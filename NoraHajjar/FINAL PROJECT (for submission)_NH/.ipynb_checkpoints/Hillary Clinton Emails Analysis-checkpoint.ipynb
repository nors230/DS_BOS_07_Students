# %%
#Hillary Clinton Email Analysis#

# %%
#data files: Aliases.csv, EmailReceivers.csv, Persons.csv, Emails.csv#

# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf
import patsy
import seaborn as sns
import matplotlib.pyplot as plt
from seaborn import plt
from sklearn.linear_model import LinearRegression
from sklearn.cross_validation import train_test_split
from sklearn.linear_model import RidgeCV
from scipy.optimize import curve_fit
# %matplotlib inline

# %%
df_aliases = pd.read_csv('~/desktop/Clinton Email Data/Aliases.csv')
df_aliases.info()
df_aliases.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 850 entries, 0 to 849
# Data columns (total 3 columns):
# Id          850 non-null int64
# Alias       850 non-null object
# PersonId    850 non-null int64
# dtypes: int64(2), object(1)
# memory usage: 26.6+ KB
#    Id                         Alias  PersonId
# 0   1                111th congress         1
# 1   2  agna usemb kabul afghanistan         2
# 2   3                            ap         3
# 3   4                      asuncion         4
# 4   5                          alec         5

# %%
df_emailreceivers = pd.read_csv('~/desktop/Clinton Email Data/EmailReceivers.csv')
df_emailreceivers.info()
df_emailreceivers.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9306 entries, 0 to 9305
# Data columns (total 3 columns):
# Id          9306 non-null int64
# EmailId     9306 non-null int64
# PersonId    9306 non-null int64
# dtypes: int64(3)
# memory usage: 290.8 KB
#    Id  EmailId  PersonId
# 0   1        1        80
# 1   2        2        80
# 2   3        3       228
# 3   4        3        80
# 4   5        4        80

# %%
df_persons = pd.read_csv('~/desktop/Clinton Email Data/Persons.csv')
df_persons.info()
df_persons.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 513 entries, 0 to 512
# Data columns (total 2 columns):
# Id      513 non-null int64
# Name    513 non-null object
# dtypes: int64(1), object(1)
# memory usage: 12.0+ KB
#    Id                          Name
# 0   1                111th Congress
# 1   2  AGNA USEMB Kabul Afghanistan
# 2   3                            AP
# 3   4                      ASUNCION
# 4   5                          Alec

# %%
df_emails = pd.read_csv('~/desktop/Clinton Email Data/Emails.csv')
df_emails.info()
df_emails.head()
#we will predominently work with this data set, as this has the body text of emails#
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7945 entries, 0 to 7944
# Data columns (total 22 columns):
# Id                              7945 non-null int64
# DocNumber                       7945 non-null object
# MetadataSubject                 7649 non-null object
# MetadataTo                      7690 non-null object
# MetadataFrom                    7788 non-null object
# SenderPersonId                  7788 non-null float64
# MetadataDateSent                7813 non-null object
# MetadataDateReleased            7945 non-null object
# MetadataPdfLink                 7945 non-null object
# MetadataCaseNumber              7945 non-null object
# MetadataDocumentClass           7945 non-null object
# ExtractedSubject                6260 non-null object
# ExtractedTo                     3288 non-null object
# ExtractedFrom                   6692 non-null object
# ExtractedCc                     2640 non-null object
# ExtractedDateSent               6628 non-null object
# ExtractedCaseNumber             7944 non-null object
# ExtractedDocNumber              7944 non-null object
# ExtractedDateReleased           7944 non-null object
# ExtractedReleaseInPartOrFull    7945 non-null object
# ExtractedBodyText               6742 non-null object
# RawText                         7945 non-null object
# dtypes: float64(1), int64(1), object(20)
# memory usage: 1.4+ MB
#    Id  DocNumber                                    MetadataSubject  \
# 0   1  C05739545                                                WOW
# 1   2  C05739546  H: LATEST: HOW SYRIA IS AIDING QADDAFI AND MOR...
# 2   3  C05739547                                      CHRIS STEVENS
# 3   4  C05739550                         CAIRO CONDEMNATION - FINAL
# 4   5  C05739554  H: LATEST: HOW SYRIA IS AIDING QADDAFI AND MOR...
#
#      MetadataTo       MetadataFrom  SenderPersonId           MetadataDateSent  \
# 0             H  Sullivan, Jacob J              87  2012-09-12T04:00:00+00:00
# 1             H                NaN             NaN  2011-03-03T05:00:00+00:00
# 2            ;H    Mills, Cheryl D              32  2012-09-12T04:00:00+00:00
# 3             H    Mills, Cheryl D              32  2012-09-12T04:00:00+00:00
# 4  Abedin, Huma                  H              80  2011-03-11T05:00:00+00:00
#
#         MetadataDateReleased  \
# 0  2015-05-22T04:00:00+00:00
# 1  2015-05-22T04:00:00+00:00
# 2  2015-05-22T04:00:00+00:00
# 3  2015-05-22T04:00:00+00:00
# 4  2015-05-22T04:00:00+00:00
#
#                                      MetadataPdfLink MetadataCaseNumber  \
# 0  DOCUMENTS/HRC_Email_1_296/HRCH2/DOC_0C05739545...       F-2015-04841
# 1  DOCUMENTS/HRC_Email_1_296/HRCH1/DOC_0C05739546...       F-2015-04841
# 2  DOCUMENTS/HRC_Email_1_296/HRCH2/DOC_0C05739547...       F-2015-04841
# 3  DOCUMENTS/HRC_Email_1_296/HRCH2/DOC_0C05739550...       F-2015-04841
# 4  DOCUMENTS/HRC_Email_1_296/HRCH1/DOC_0C05739554...       F-2015-04841
#
#                          ...                         ExtractedTo  \
# 0                        ...                                 NaN
# 1                        ...                                 NaN
# 2                        ...                                  B6
# 3                        ...                                 NaN
# 4                        ...                                 NaN
#
#                               ExtractedFrom         ExtractedCc  \
# 0  Sullivan, Jacob J <Sullivan11@state.gov>                 NaN
# 1                                       NaN                 NaN
# 2       Mills, Cheryl D <MillsCD@state.gov>        Abedin, Huma
# 3       Mills, Cheryl D <MillsCD@state.gov>  Mitchell, Andrew B
# 4                                       NaN                 NaN
#
#                         ExtractedDateSent ExtractedCaseNumber  \
# 0  Wednesday, September 12, 2012 10:16 AM        F-2015-04841
# 1                                     NaN        F-2015-04841
# 2  Wednesday, September 12, 2012 11:52 AM        F-2015-04841
# 3   Wednesday, September 12,2012 12:44 PM        F-2015-04841
# 4                                     NaN        F-2015-04841
#
#   ExtractedDocNumber ExtractedDateReleased ExtractedReleaseInPartOrFull  \
# 0          C05739545            05/13/2015              RELEASE IN FULL
# 1          C05739546            05/13/2015              RELEASE IN PART
# 2          C05739547            05/14/2015              RELEASE IN PART
# 3          C05739550            05/13/2015              RELEASE IN PART
# 4          C05739554            05/13/2015              RELEASE IN PART
#
#                                    ExtractedBodyText  \
# 0                                                NaN
# 1  B6\nThursday, March 3, 2011 9:45 PM\nH: Latest...
# 2                                                Thx
# 3                                                NaN
# 4  H <hrod17@clintonemail.com>\nFriday, March 11,...
#
#                                              RawText
# 0  UNCLASSIFIED\nU.S. Department of State\nCase N...
# 1  UNCLASSIFIED\nU.S. Department of State\nCase N...
# 2  UNCLASSIFIED\nU.S. Department of State\nCase N...
# 3  UNCLASSIFIED\nU.S. Department of State\nCase N...
# 4  B6\nUNCLASSIFIED\nU.S. Department of State\nCa...
#
# [5 rows x 22 columns]

# %%
#now that we have loaded our data sets, we want to merge them to dataset df_emails to provide the most insight possible, in terms of senders and receivers#

# %%
#Let's look at who RECEIVED the most emails#

df_emails.MetadataTo.value_counts()

#looks like it is Hillary Clinton, followed by Huma Abedinh and Jacob Sullivan#
# Out:
# H                                   1906
# Abedin, Huma                        1380
# Mills, Cheryl D                     1146
# Sullivan, Jacob J                    750
# sbwhoeop                             316
# Jiloty, Lauren C                     302
# Valmoro, Lona J                      146
# Slaughter, Anne-Marie                127
# Verma, Richard R                     115
# PIR                                  108
# McHale, Judith A                      73
# hrod17@clintonemail.com               71
# Muscatine, Lissa                      70
# MillsCD@state.gov                     64
# Verveer, Melanne S                    59
# AbedinH@state.gov                     49
# Mills, Cheryl                         46
# cheryl.mills                          44
# Sid                                   43
# jake.sullivan                         38
# Sullivan, Jake                        37
# Talbott, Strobe                       36
# Reines, Philippe I                    34
# Ebeling, Betsy                        30
# Hanley, Monica R                      27
# SullivanJJ@state.gov                  24
# Russo, Robert V                       23
# JilotyLC@state.gov                    21
# Balderston, Kris M                    21
# Blair, Cherie                         20
#                                     ...
# Calivis, Maria                         1
# Tandem, Neera                          1
# Donilon, Thomas E                      1
# Norman, Nicholas                       1
# EAP/K:Rosenberger, L                   1
# Jiloty. Lauren C                       1
# Mikulski,BAM (Mikulski)                1
# Balderstone, Kris M                    1
# Reines, Philippe                       1
# jake. sullivan                         1
# latimes.com                            1
# Lou de Bac, G/TIP                      1
# Muscatine Lissa                        1
# PRM/MCE:Wills, G                       1
# Colin Powell                           1
# Gordon. Philip H                       1
# Carson, Johnnie                        1
# Kelly, Ian                             1
# Butzgy, Christopher H                  1
# Heintz                                 1
# Campbell, Piper                        1
# BLAIR CHERIE                           1
# Hillary Rodham Clinton                 1
# S/SRGIA                                1
# Cheryl.mills                           1
# Shah, Rajiv                            1
# Reines, Phillippe I                    1
# Walmoro, Lona J                        1
# U.S. Global Leadership Coalition       1
# NEA/IPA:Knopf, Payton                  1
# Name: MetadataFrom, dtype: int64

# %%
#and who sent the most?#
df_emails.MetadataFrom.value_counts()
#Hillary, Huma, and Cheryl Mills are the top senders - interesting and makes sense, Hillary was the top RECEIVER of emails, as she was SecState, but she was not the top sender - she sent a lot, but so did her Chief of Staff (Huma), and her special advisor Cheryl Mills#
# Out:
# H                                   1906
# Abedin, Huma                        1380
# Mills, Cheryl D                     1146
# Sullivan, Jacob J                    750
# sbwhoeop                             316
# Jiloty, Lauren C                     302
# Valmoro, Lona J                      146
# Slaughter, Anne-Marie                127
# Verma, Richard R                     115
# PIR                                  108
# McHale, Judith A                      73
# hrod17@clintonemail.com               71
# Muscatine, Lissa                      70
# MillsCD@state.gov                     64
# Verveer, Melanne S                    59
# AbedinH@state.gov                     49
# Mills, Cheryl                         46
# cheryl.mills                          44
# Sid                                   43
# jake.sullivan                         38
# Sullivan, Jake                        37
# Talbott, Strobe                       36
# Reines, Philippe I                    34
# Ebeling, Betsy                        30
# Hanley, Monica R                      27
# SullivanJJ@state.gov                  24
# Russo, Robert V                       23
# JilotyLC@state.gov                    21
# Balderston, Kris M                    21
# Blair, Cherie                         20
#                                     ...
# Calivis, Maria                         1
# Tandem, Neera                          1
# Donilon, Thomas E                      1
# Norman, Nicholas                       1
# EAP/K:Rosenberger, L                   1
# Jiloty. Lauren C                       1
# Mikulski,BAM (Mikulski)                1
# Balderstone, Kris M                    1
# Reines, Philippe                       1
# jake. sullivan                         1
# latimes.com                            1
# Lou de Bac, G/TIP                      1
# Muscatine Lissa                        1
# PRM/MCE:Wills, G                       1
# Colin Powell                           1
# Gordon. Philip H                       1
# Carson, Johnnie                        1
# Kelly, Ian                             1
# Butzgy, Christopher H                  1
# Heintz                                 1
# Campbell, Piper                        1
# BLAIR CHERIE                           1
# Hillary Rodham Clinton                 1
# S/SRGIA                                1
# Cheryl.mills                           1
# Shah, Rajiv                            1
# Reines, Phillippe I                    1
# Walmoro, Lona J                        1
# U.S. Global Leadership Coalition       1
# NEA/IPA:Knopf, Payton                  1
# Name: MetadataFrom, dtype: int64

# %%
df_emails.ExtractedFrom.value_counts()
# Out:
# H <hrod17@clintonemail.com>                            1415
# Abedin, Huma <AbedinH@state.gov>                       1034
# Mills, Cheryl D <MillsCD@state.gov>                     890
# Sullivan, Jacob J <SullivanJJ@state.gov>                425
# Jiloty, Lauren C <JilotyLC@state.gov>                   248
# H <hrod17@clintonemail.com >                            210
# sbwhoeop                                                190
# Valmoro, Lona J <ValmoroU@state.gov>                    105
# Abedin, Huma <AbedinH©state.gov>                        105
# Slaughter, Anne-Marie <SlaughterA@state.gov>             98
# Verma, Richard R <VermaRR@state.gov>                     89
# Mills, Cheryl D <MillsCD©state.gov>                      86
# Huma Abedin                                              55
# PIR <preines                                             53
# McHale, Judith A <McHaleJA@state.gov>                    53
# Verveer, Melanne S <VerveerMS@state.gov>                 46
# Sullivan, Jacob J <SullivanJJ©state.gov>                 46
# Sid                                                      44
# Muscatine, Lissa <MuscatineL@state.gov>                  41
# Sullivan, Jacob J <Sullivann@state.gov>                  39
# Jiloty, Lauren C <JilotyLC©state.gov>                    36
# Reines, Philippe I <reinesp@state.gov>                   32
# Sullivan, Jacob 1 <SullivanJJ@state.gov>                 29
# Abedin, Huma <AbedinH@state.goy>                         28
# Cheryl Mills                                             27
# cheryl.mills                                             24
# Huma Abedin <Huma@clintonemail.com>                      24
# Mills, Cheryl D <MillsCD@state.goy>                      22
# Balderston, Kris M <BalderstonKM@state.gov>              21
# Russo, Robert V <RussoRV@state.gov>                      20
#                                                        ...
# Koh, Harold Hongju <KohliFf@state.gov>                    1
# Sullivan, Jacob J <Sullivardi@state.gov>                  1
# Sullivan, Jacob J <Sullivarth@state.gov>                  1
# Hemmen, Chris                                             1
# Recos                                                     1
# McHale, Judith A <McHaleJA©state.goy>                     1
# Adler, Caroline E <AdlerCE@state.gov>                     1
# Crowley, Philip J <CrowleyP1@state.gov>                   1
# Jiloty, Lauren C <JilotylC@state.gov>                     1
# Sullivan, Jacob1 <SullivanJJ@state.gov>                   1
# Eizenstat, Stuart                                         1
# Sullivan, Jacobi <Sullivarill@state.gov>                  1
# Daniel Baer <                                             1
# H [mailto:HDR22@clintonemail.com]                         1
# Colin Powell                                              1
# PIR <preines(i _                                          1
# Abedin,,Huma <AbedinH@state.goy>                          1
# Sullivan, Jacob J <Sullivarill@state.gov>                 1
# Shannon, Thomas A                                         1
# Philippe Reines < B6                                      1
# Mills, Cheryl D [mailto:MillsCD@stategovi                 1
# Wendy Sherman <                                           1
# H <hrod17@clintonernail.com >                             1
# Lauren Jiloty <laurenjiloty B6                            1
# Mikulski, BAM (Mikulski) <BAM@Mikulski.senate.gov>.       1
# cheryl.mill                                               1
# Sullivan, Jacob J<SullivanJJ@state.gov>                   1
# Mills, Cheryl D <MiIIsCD©state.gov>                       1
# Sullivan, Jacob J <Sullivanli@stategov>                   1
# Sullivan, Jacob I <Sullivanli@state.gove                  1
# Name: ExtractedFrom, dtype: int64

# %%
df_emails.ExtractedCc.value_counts()
# Out:
# Abedin, Huma                                                                                     213
# Huma Abedin                                                                                      135
# Mills, Cheryl D                                                                                   78
# Sullivan, Jacob J                                                                                 77
# Abedin, Huma <AbedinH@state.gov>                                                                  72
# Oscar Flores                                                                                      64
# SES-O_Shift-II                                                                                    62
# H                                                                                                 46
# Toiv, Nora F                                                                                      42
# Sullivan, Jacob                                                                                   34
# SES-O_Shift-III                                                                                   32
# Mills, Cheryl D <MillsCD@state.gov>                                                               30
# 'sullivanjj@state.gov'                                                                            23
# H2                                                                                                22
# SES-0_0S; SES-O_Shift-I                                                                           18
# Verma, Richard R                                                                                  18
# Sullivan, Jacob J; Abedin, Huma                                                                   17
# Abedin, Huma; Sullivan, Jacob J                                                                   16
# S_SpecialAssistants                                                                               15
# SES-O_Shift-I                                                                                     15
# Valmoro, Lona J <ValmoroU@state.gov>                                                              15
# SES-O_OS                                                                                          15
# SES-0                                                                                             15
# Jiloty, Lauren C                                                                                  14
# Huma Abed in                                                                                      13
# 'ValmoroU@state.gov'                                                                              12
# Jake Sullivan                                                                                     12
# Sullivan, Jacob J <SullivanJJ@state.gov>                                                          12
# Mills, Cheryl D; Sullivan, Jacob J                                                                11
# SES-0_0S; SES-O_Shift-II                                                                          11
#                                                                                                 ...
# Gonzalez, Juan S <GonzalezJS©state.gov>:                                                           1
# Stremlau, Matthew H; Plowden, Marisa L; Klevorick, Caitlin B; Toiv, Nora F                         1
# Jacobs, Janice L; Feltman, Jeffrey D; Macmanus, Joseph E; Fogarty, Daniel 3                        1
# Sullivan, Jacob J; Carson, Johnnie                                                                 1
# Yamamoto, Donald Y                                                                                 1
# NEWS-WHA; SES-Line_UNGA; M_SpecialAssistants; SES-O_SWO-Only                                       1
# Kelly, Craig A; Riva-Geoghegan, Margarita M                                                        1
# 'sbwhoeop <sbwhoeor                                                                                1
# Zeya, Uzra S; Burns, William 3; Kennedy, Patrick F; Macmanus, Joseph E (S); Sullivan, Jacob J      1
# 'mchaleja@state.gov'                                                                               1
# Fuchs, Michael H; Adler, Caroline E                                                                1
# 'Abedinhi@state.goV; "MillsCD@state.gov'                                                           1
# SES-0_0S; SES-O_Shift-I; SES-O_Shift-II                                                            1
# Aguilera, Patricia                                                                                 1
# ChoIlet, Derek H <CholletDH@state.gov>                                                             1
# cheryl.mills _                                                                                     1
# Otero, Maria                                                                                       1
# S_SpecialAssIstants                                                                                1
# Toiv, Nora F; Pena, Laura                                                                          1
# Ensher, Henry S; Campbell, Piper                                                                   1
# SES-O_Shift-1                                                                                      1
# Bagley, Elizabeth F; Abedin, Huma                                                                  1
# Abet:lin, Huma; Hume Abedin; Valmoro, Lona ./                                                      1
# Mills, Cheryl D; Ross, Alec J                                                                      1
# Feeley, John D (Mexico City); Restrepo Dan                                                         1
# Laszczych, Joanne; Gelber, Ethan M; Balenger, De'Ara N                                             1
# Maria McFarland                                                                                    1
# Valmoro, Lona J; Huma A edin                                                                       1
# Reines, Philippe I; Mills, Cheryl D                                                                1
# Wells, Alice G; Rana, Gautam A; Verma, Richard R                                                   1
# Name: ExtractedCc, dtype: int64

# %%
#something interesting - the To and From columns have only one person - from should be unique (can't send an email from more than one account at a time)but the "To" form doesn't have to go to only one person - the CC column, added to the "To" column, reflects more accurately who is actually receiving these emails - food for thought to combine these into a super "To" column and run analysis on that - #

# %%
# also would like to clean up the names so that only the alias turns up when called- add a column?#

# %%
#lets plot the ExtractedFrom values (more interesting than the two)#

# %%
df_emails.ExtractedFrom.value_counts().plot(kind='bar')

# %%
df_emails.MetadataFrom.value_counts().plot(kind='bar')

# %%
df_emails.MetadataTo.value_counts().plot(kind='bar')

# %%
from wordcloud import WordCloud, STOPWORDS

#continue to build out a wordcloud with the raw text of emails#

# %%
#other analysis: 1) sentiment analysis with Naive Bayes classification 07#
#2) LSI Latent Semantic Indexing - this was the lecture on natural language processing#
#3) Flesch-Kinkaid analysis - who has the most complex sentences

# %%
pip install textstat
# Out:
#   File "<ipython-input-1-a6bd826e5578>", line 1
#     pip install textstat
#               ^
# SyntaxError: invalid syntax

# %%
import readability

# %%
import textstat

# %%
from __future__ import division, print_function, unicode_literals
import io
import os
import re
import sys
import math
import codecs
import getopt
import subprocess
import collections
from readability.langdata import LANGDATA

# %%
def getmeasures(text, lang='en', merge=False):
# Out:
#   File "<ipython-input-9-6e790d253d96>", line 1
#     def getmeasures(text, lang='en', merge=False):
#                                                   ^
# SyntaxError: unexpected EOF while parsing

# %%
#moving to LSI analysis here, will come back to these two packages

# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf
import patsy
import seaborn as sns
from seaborn import plt
from sklearn.linear_model import LinearRegression
from sklearn.cross_validation import train_test_split
from sklearn.linear_model import RidgeCV
# %matplotlib inline
# Out:
# /Users/norahajjar/anaconda/lib/python2.7/site-packages/matplotlib/__init__.py:872: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
#Import sklearn.cross_validation.train_test_split
from sklearn.cross_validation import train_test_split
X_train, X_test, y_train, y_test = train_test_split(test_images, test_labels, test_size=0.3)

# %%
df_emails.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7945 entries, 0 to 7944
# Data columns (total 22 columns):
# Id                              7945 non-null int64
# DocNumber                       7945 non-null object
# MetadataSubject                 7649 non-null object
# MetadataTo                      7690 non-null object
# MetadataFrom                    7788 non-null object
# SenderPersonId                  7788 non-null float64
# MetadataDateSent                7813 non-null object
# MetadataDateReleased            7945 non-null object
# MetadataPdfLink                 7945 non-null object
# MetadataCaseNumber              7945 non-null object
# MetadataDocumentClass           7945 non-null object
# ExtractedSubject                6260 non-null object
# ExtractedTo                     3288 non-null object
# ExtractedFrom                   6692 non-null object
# ExtractedCc                     2640 non-null object
# ExtractedDateSent               6628 non-null object
# ExtractedCaseNumber             7944 non-null object
# ExtractedDocNumber              7944 non-null object
# ExtractedDateReleased           7944 non-null object
# ExtractedReleaseInPartOrFull    7945 non-null object
# ExtractedBodyText               6742 non-null object
# RawText                         7945 non-null object
# dtypes: float64(1), int64(1), object(20)
# memory usage: 1.4+ MB
