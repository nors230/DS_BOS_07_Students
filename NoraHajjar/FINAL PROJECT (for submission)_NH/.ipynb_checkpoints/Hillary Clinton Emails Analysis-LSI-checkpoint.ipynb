# %%
#Hillary Clinton Email Analysis LSI#

# %%
#data files: Emails.csv#

# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf
import patsy
import seaborn as sns
import matplotlib.pyplot as plt
from seaborn import plt
from sklearn.linear_model import LinearRegression
from sklearn.cross_validation import train_test_split
from sklearn.linear_model import RidgeCV
from scipy.optimize import curve_fit
# %matplotlib inline
# Out:
# /Users/norahajjar/anaconda/lib/python2.7/site-packages/matplotlib/__init__.py:872: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
df_emails = pd.read_csv('~/desktop/Clinton Email Data/Emails.csv', encoding="utf-8")
df_emails.info()
#we will predominently work with this data set, as this has the body text of emails#
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7945 entries, 0 to 7944
# Data columns (total 22 columns):
# Id                              7945 non-null int64
# DocNumber                       7945 non-null object
# MetadataSubject                 7649 non-null object
# MetadataTo                      7690 non-null object
# MetadataFrom                    7788 non-null object
# SenderPersonId                  7788 non-null float64
# MetadataDateSent                7813 non-null object
# MetadataDateReleased            7945 non-null object
# MetadataPdfLink                 7945 non-null object
# MetadataCaseNumber              7945 non-null object
# MetadataDocumentClass           7945 non-null object
# ExtractedSubject                6260 non-null object
# ExtractedTo                     3288 non-null object
# ExtractedFrom                   6692 non-null object
# ExtractedCc                     2640 non-null object
# ExtractedDateSent               6628 non-null object
# ExtractedCaseNumber             7944 non-null object
# ExtractedDocNumber              7944 non-null object
# ExtractedDateReleased           7944 non-null object
# ExtractedReleaseInPartOrFull    7945 non-null object
# ExtractedBodyText               6742 non-null object
# RawText                         7945 non-null object
# dtypes: float64(1), int64(1), object(20)
# memory usage: 1.4+ MB

# %%
#other analysis: 1) sentiment analysis with Naive Bayes classification 07#
#2) LSI Latent Semantic Indexing - this was the lecture on natural language processing#
#3) Flesch-Kinkaid analysis - who has the most complex sentences 
#4) Naive Bayes predict who the sender is based on the Raw Text

# %%
#Let's do LSI!

# %%
#time to train/test/split otherwise we will have an overfitting problem
# Import train_test_split
from sklearn.cross_validation import train_test_split
# Split the data into a 70/30 train/test split
df_emails_train, df_emails_test = train_test_split(df_emails.RawText, test_size=0.3)
df_emails_sender_train, df_emails_sender_test = train_test_split(df_emails.MetadataFrom, test_size=0.3)

# %%
# We're not concerned with the category for now, so select out only the text column into a Series object 'docs'
docs = df_emails_train
docs.head()
# Out:
# 480     UNCLASSIFIED U.S. Department of State Case No....
# 1537    UNCLASSIFIED U.S. Department of State Case No....
# 5320    UNCLASSIFIED U.S. Department of State Case No....
# 7336    UNCLASSIFIED U.S. Department of State Case No....
# 565     UNCLASSIFIED U.S. Department of State Case No....
# Name: RawText, dtype: object

# %%
# Let's load the nltk English stopwords list to ignore those in our analysis
import nltk
from nltk.corpus import stopwords
## Download various nltk corpora (used for stopwords here)
#nltk.download()
## Print all english stopwords
stopwords = stopwords.words('english')

# %%
'''
The way we're going to attack this is to build out the TDM matrix with the documents as rows and terms as columns
and then we'll call the transpose operator to flip it to the representation we need for LSI.

We need the following:
    1.  Dictionary of word --> index to define vectors (index for each term)
    2.  Dictionary of word --> total count to get the global (IDF)
    3.  Dictionary of word --> document count for each document to get the local (TF) weighting
'''
# Implement a function that returns the 3 dictionaries that we need above
def find_frequencies(docs):
    term_indices = {} ## This is #1 above
    currentIndex = 0 ## This is the counter to make sure we correctly populate the term indices in order
    corpus_bag = {} ## This is #2 above
    doc_bags = [] ## This is the collection for #3 above
    for i, doc in docs.iteritems():
        doc_bag = {} ## This is the dictionary of term frequencies for the doc we're currently examining, doc_bags stores a collection of these
        ## TODO: Tokenize each document with nltk
        doc_tokens = nltk.word_tokenize(doc)
        ## TODO: For each token in the current document:
        for word in doc_tokens:
            ## Optionally ignore stopword and continue
            ## Throw out stopwords
            ##if word in stopwords:
                ##    continue
            ## If the word is new (not in term_indices): 
            if word not in term_indices:
                ## add it to term_indices and give it the index value currentIndex, increment currentIndex
                term_indices[word] = currentIndex
                currentIndex += 1
                ## add it to the corpus_bag with count 1
                corpus_bag[word] = 1
                ## add it to the current doc_bag with count 1
                doc_bag[word] = 1
            ## If the word is not new:
            else:
                ## increment the corpus_bag
                corpus_bag[word] = corpus_bag[word] + 1
                ## If the word is already in the doc_bag, increment that counter, else set it to 1
                if word in doc_bag:
                    doc_bag[word] = doc_bag[word] + 1
                else:
                    doc_bag[word] = 1
        doc_bags.append(doc_bag)
    return term_indices, corpus_bag, doc_bags

# %%
term_indices, corpus_bag, doc_bags = find_frequencies(docs)

# %%
print len(term_indices)
print term_indices['UNCLASSIFIED']
#print term_indices['']
# Out:
# 75788
# 0

# %%
print len(corpus_bag)
print corpus_bag['UNCLASSIFIED']
# Out:
# 75788
# 18809

# %%
print len(doc_bags[0])
print doc_bags[0]
# Out:
# 91
# {u'all': 1, u'Wed': 1, u'not': 1, u'PART': 1, u'Department': 2, u'Today': 2, u'Wireless': 1, u'Verizon': 1, u',': 3, u'Minyon': 1, u'31:8-9': 1, u'Burns': 1, u'<': 1, u'@': 2, u'H': 2, u'hrod17': 1, u'judge': 1, u'clintonemail.com': 1, u'Moore': 1, u'--': 1, u'B6': 1, u'Subject': 2, u'Case': 2, u'From': 2, u'State': 2, u'are': 1, u'destitute': 1, u'Sent': 3, u'out': 1, u'for': 4, u'defend': 1, u'print': 1, u';': 2, u'Proverbs': 1, u'U.S.': 2, u'RELEASE': 1, u'of': 4, u'Rob': 1, u"state.gov'": 1, u'BlackBerry': 1, u'20:13:00': 1, u"'Russorv": 1, u'Speak': 2, u'No': 4, u'June': 1, u'speak': 1, u'from': 1, u'Fw': 1, u'Jun': 1, u'.': 8, u'UNCLASSIFIED': 2, u'Date': 2, u'themselves': 1, u':': 11, u'type': 1, u'>': 1, u'Reflection': 2, u'Original': 1, u'those': 1, u'me': 1, u'10': 1, u'rights': 2, u'this': 1, u'up': 2, u'can': 1, u'F-2014-20439': 2, u'my': 1, u'and': 2, u'Thursday': 1, u"''": 2, u'To': 2, u'in': 1, u'pis': 1, u'11': 1, u'8:04': 1, u'needy': 1, u'BIG': 1, u'Strider': 1, u'poor': 1, u'fairly': 1, u"'s": 2, u'Thx': 1, u'Doc': 2, u'who': 2, u'AM': 1, u'IN': 1, u'Message': 1, u'06/30/2015': 2, u'C05758748': 2, u'the': 3, u'2009': 2}

# %%
## Useful imports
import math
import scipy
from scipy import linalg

# %%
## Implement a function that uses the corpus_bag and doc_bags found above to compute the global weighting (idf) term
def compute_global_weight(corpus_bag, doc_bags):
    global_weights = {} ## A dictionary of term --> global weight (the idf components) using entropy weighting
    ## TODO: Define a variable logn which is the log base 2 of the number of documents in the set
    logn = math.log(len(doc_bags), 2)
    ## TODO: For each doc_bag:
    for doc_bag in doc_bags:
        ## TODO: For each term in the doc_bag
        for term in doc_bag:
            ## TODO: If the term is not in global_weights, initialize it with value 1
            if term not in global_weights:
                global_weights[term] = 1
            ## TODO: Calculate p_ij and increase the term's global weight by p_ij * log(p_ij) / logn
            local_count = doc_bag[term] + 0.0
            global_count = corpus_bag[term]
            pij = local_count/global_count
            global_weights[term] += pij*math.log(pij,2)/logn
    return global_weights

# %%
global_weights = compute_global_weight(corpus_bag, doc_bags)

# %%
print global_weights['UNCLASSIFIED']
# Out:
# 0.0348528001542

# %%
## Finish the job with a function build_TDM that takes a Series 'docs' and outputs the TDM (a numpy matrix), make it also 
## return the term_indices and global weights as well
def build_TDM(docs):
    ## TODO: Use your first 2 functions from above to populate the term_indices, corpus_bag, doc_bags and global_weights
    term_indices, corpus_bag, doc_bags = find_frequencies(docs)
    global_weights = compute_global_weight(corpus_bag, doc_bags)
    ## TODO: For each doc_bag, generate a doc_vec and add to doc_vecs (these are the "vectors" for each document with weighting)
    doc_vecs = []
    for doc_bag in doc_bags:
        ## TODO: Initialize 'doc_vec' as a list of zeroes with 1 entry per unique term
        doc_vec = [0]*len(corpus_bag)
        ## TODO: For each term in the doc_bag, add the appropriate value into the appropriate place in the doc_vec
        ## NOTE: Need to take advantage of term_indices to get the right index, global_weights and doc_bag to get the value
        for term in doc_bag:
            index = term_indices[term]
            value = global_weights[term]*math.log(doc_bag[term] + 1.0, 2)
            doc_vec[index] = value
        doc_vecs.append(doc_vec)
    ## TODO: Generate a numpy matrix from doc_vecs, and take it's transpose to give the TDM, return that
    tdmatrix = np.matrix(doc_vecs).transpose()
    return term_indices, global_weights, tdmatrix

# %%
term_indices, global_weights, tdmatrix = build_TDM(docs)

# %%
## Run the svd to yield the full term and document space matrices
## WARNING: This is the computationally intensive step, it will take a long time, so make sure you've taken care of everything before
## this as best as possible so you don't have to do it multiple times
## Once this step is completed, essentially all the computational work is done, you have a trained LSI space!
T,sigma,D_trans = linalg.svd(tdmatrix, full_matrices=False)

# %%
## Truncate the resulting matrices to dimension k (you select this dimension, higher values retain more information at complexity cost)
k = 100
m = T.shape[0]
n = D_trans.shape[1]
T_k = T[0:m, 0:k]
print T_k.shape
D_trans_k = D_trans[0:k, 0:n]
print D_trans_k.shape
sigma_inv = np.linalg.inv(linalg.diagsvd(sigma, n, n))
sigma_inv_k = sigma_inv[0:k, 0:k]
print sigma_inv_k.shape
# Out:
# (75788, 100)
# (100, 5561)
# (100, 100)

# %%
## Function that folds a new document into an existing LSI space (space designated by global weightings, term indices, and T_k and sigma_inv_k)
def fold_doc(doc_text, term_indices, global_weights, T_k, sigma_inv_k):
    tokens = nltk.word_tokenize(doc_text)
    doc_bag = {}
    for token in tokens:
        if token in doc_bag:
            doc_bag[token] = doc_bag[token] + 1
        else:
            doc_bag[token] = 1
    a_vec = [0]*len(term_indices)
    for term in doc_bag:
        if term in term_indices:
            index = term_indices[term]
            a_vec[index] = global_weights[term]*math.log(doc_bag[term] + 1.0, 2)
    a = np.matrix(a_vec)
    folded_vec = np.dot(np.dot(a, T_k), sigma_inv_k)
    return folded_vec

# %%
def cosine_sim(a, b): 
    return linalg.norm(np.dot(a/linalg.norm(a), b.transpose()/linalg.norm(b)))

# %%
doc1 = docs[0]
doc2 = docs[2]
vec1 = fold_doc(doc1, term_indices, global_weights, T_k, sigma_inv_k)
vec2 = fold_doc(doc2, term_indices, global_weights, T_k, sigma_inv_k)
print cosine_sim(vec1, vec2)
# Out:
# 0.959727302582

# %%
#okay now we have built out our space! let's do something with it! instead of the categorization problem that we used in class, lets try to predict who the SENDER is - in our dataset we want to use MetadataFrom and RawText

# %%
df_emails_train, df_emails_test = train_test_split(df_emails, test_size=0.3)

# %%
#this is where I am stuck for now -

# %%
## Classify documents
def classify_docs(df_test, term_indices, global_weights, T_k, sigma_inv_k):
    test_doc_count = 0
    correct_count = 0
    ## TODO: iterate through the rows of df_test using iterrows
    for row in df_test.iterrows():
        ## TODO: Retrive the actual cat and test for each row
        test_cat = row[1]['cat']
        test_doc = row[1]['text']
        ## TODO: Fold the test document into the space to give it a vector
        folded_vec = fold_doc(test_doc, term_indices, global_weights, T_k, sigma_inv_k)
        ## TODO: Compare the resultant vectors via cosine similarity and give each test document the category 
        ## of the training document closest to it.  Print out the right and predicted categories.  Keep track of right/wrong
        best_score = -1.0
        record = None
        index = 0
        for j in xrange(0, D_trans_k.shape[1]):
            training_vec = D_trans_k[0:k, j:j+1]
            score = np.dot(folded_vec, training_vec)/linalg.norm(folded_vec)/linalg.norm(training_vec)
            if score > best_score:
                best_score = score
                record = reuters_df_train[j:j+1]
                index = j
        found_cat = record.cat[index]
        print test_cat + "," + found_cat
        test_doc_count += 1
        if test_cat==found_cat:
            correct_count += 1
    ## TODO: Print out the summary results
    print "Total Docs Test: " + str(test_doc_count)
    print "Total Correct: " + str(correct_count)
    print "Accuracy: " + str((correct_count+0.0)/test_doc_count)
    return

# %%
df_test = df_emails_test
classify_docs(df_test, term_indices, global_weights, T_k, sigma_inv_k)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-3573444eeb55> in <module>()
#       1 df_test = df_emails_test
# ----> 2 classify_docs(df_test, term_indices, global_weights, T_k, sigma_inv_k)
#
# <ipython-input-36-75a99cc51b3b> in classify_docs(df_test, term_indices, global_weights, T_k, sigma_inv_k)
#       4     correct_count = 0
#       5     ## TODO: iterate through the rows of df_test using iterrows
# ----> 6     for row in df_test.iterrows():
#       7         ## TODO: Retrive the actual cat and test for each row
#       8         test_cat = row[1]['cat']
#
# /Users/norahajjar/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    2358                 return self[name]
#    2359             raise AttributeError("'%s' object has no attribute '%s'" %
# -> 2360                                  (type(self).__name__, name))
#    2361
#    2362     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'iterrows'

# %%
#moving to Naive Bayes analysis here - we want to be able to predict who the sender is, based on their email text

# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf
import patsy
import seaborn as sns
from seaborn import plt
from sklearn.linear_model import LinearRegression
from sklearn.cross_validation import train_test_split
from sklearn.linear_model import RidgeCV
# %matplotlib inline
# Out:
# /Users/norahajjar/anaconda/lib/python2.7/site-packages/matplotlib/__init__.py:872: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
#Import sklearn.cross_validation.train_test_split
from sklearn.cross_validation import train_test_split
X_train, X_test, y_train, y_test = train_test_split(test_images, test_labels, test_size=0.3)
#

# %%
#lets try this - predict who the email is from. Use RawText column, and MetaDataFrom, see if we can predict using Naive Bayes

# %%
#first lets take out NaN to clean up data
#results tell us that MetaDataFrom has 7788 rows, and RawText has 7945 rows - need to take some of these out b/c there is no sender, won't be able to test on these. Let's run the on MetaDataFrom 
df_emails.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7945 entries, 0 to 7944
# Data columns (total 22 columns):
# Id                              7945 non-null int64
# DocNumber                       7945 non-null object
# MetadataSubject                 7649 non-null object
# MetadataTo                      7690 non-null object
# MetadataFrom                    908 non-null object
# SenderPersonId                  7788 non-null float64
# MetadataDateSent                7813 non-null object
# MetadataDateReleased            7945 non-null object
# MetadataPdfLink                 7945 non-null object
# MetadataCaseNumber              7945 non-null object
# MetadataDocumentClass           7945 non-null object
# ExtractedSubject                6260 non-null object
# ExtractedTo                     3288 non-null object
# ExtractedFrom                   6692 non-null object
# ExtractedCc                     2640 non-null object
# ExtractedDateSent               6628 non-null object
# ExtractedCaseNumber             7944 non-null object
# ExtractedDocNumber              7944 non-null object
# ExtractedDateReleased           7944 non-null object
# ExtractedReleaseInPartOrFull    7945 non-null object
# ExtractedBodyText               6742 non-null object
# RawText                         7945 non-null object
# dtypes: float64(1), int64(1), object(20)
# memory usage: 1.4+ MB

# %%
#df_emails.MetadataFrom = df_emails.dropna()
#revisit this
#try to remove NaN from the entire dataset instead, see what happens
#df_emails = df_emails.dropna()
df_emails = df_emails.dropna(how='all') #'any' gets the same result

# %%
df_emails.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 908 entries, 2 to 7923
# Data columns (total 22 columns):
# Id                              908 non-null int64
# DocNumber                       908 non-null object
# MetadataSubject                 908 non-null object
# MetadataTo                      908 non-null object
# MetadataFrom                    908 non-null object
# SenderPersonId                  908 non-null float64
# MetadataDateSent                908 non-null object
# MetadataDateReleased            908 non-null object
# MetadataPdfLink                 908 non-null object
# MetadataCaseNumber              908 non-null object
# MetadataDocumentClass           908 non-null object
# ExtractedSubject                908 non-null object
# ExtractedTo                     908 non-null object
# ExtractedFrom                   908 non-null object
# ExtractedCc                     908 non-null object
# ExtractedDateSent               908 non-null object
# ExtractedCaseNumber             908 non-null object
# ExtractedDocNumber              908 non-null object
# ExtractedDateReleased           908 non-null object
# ExtractedReleaseInPartOrFull    908 non-null object
# ExtractedBodyText               908 non-null object
# RawText                         908 non-null object
# dtypes: float64(1), int64(1), object(20)
# memory usage: 163.2+ KB

# %%
#revisit dropping nulls, lets see what runs first - for now we are going with 908 lines which is kind of a small number... let's see how it works 
#another way to do this is to predict the MetadataFrom as the SenderPersonId, so that it remails a numerical value - lets try this

# %%
#time to train/test/split otherwise we will have an overfitting problem
# Import train_test_split
from sklearn.cross_validation import train_test_split
# Split the data into a 70/30 train/test split
X_train, X_test, y_train, y_test = train_test_split(df_emails.RawText, df_emails.SenderPersonId, test_size=0.3)

# %%
# Print the shape of X_train
print X_train.shape
# Print X_train
print X_train
# Out:
#   File "<ipython-input-69-72d9cabc541e>", line 2
#     print X_train.shape
#                 ^
# SyntaxError: invalid syntax

# %%
# Print the shape of X_test
X_test.shape
# Out:
# (273,)

# %%
y_test.shape
# Out:
# (273,)

# %%
#Import CountVectorizer
from sklearn.feature_extraction.text import CountVectorizer
#Create a CountVectorizer with binary=True so all nonzero counts are given value 1
binary_vect = CountVectorizer(decode_error = 'ignore', binary=True)
# Call fit to do our vectorization
binary_vect.fit(X_train)
# Print out all of the tokens in the dictionary
binary_vect.get_feature_names()
# Out:
# [u'00',
#  u'000',
#  u'0000',
#  u'0001',
#  u'001',
#  u'008',
#  u'00am',
#  u'00b',
#  u'00n',
#  u'00pm',
#  u'00v',
#  u'01',
#  u'010000000000',
#  u'0102',
#  u'0105',
#  u'011',
#  u'0129',
#  u'02',
#  u'0203',
#  u'020510',
#  u'021',
#  u'0265',
#  u'0271',
#  u'03',
#  u'0301',
#  u'0308',
#  u'031406z',
#  u'0323',
#  u'0380',
#  u'0390',
#  u'04',
#  u'0400',
#  u'0418',
#  u'04841',
#  u'05',
#  u'0500',
#  u'050710',
#  u'0509',
#  u'0517',
#  u'055',
#  u'05am',
#  u'06',
#  u'0600',
#  u'060209',
#  u'0603',
#  u'0604',
#  u'0605',
#  u'0609',
#  u'062',
#  u'06397276',
#  u'07',
#  u'0710',
#  u'0714',
#  u'0730',
#  u'0745',
#  u'07oct',
#  u'08',
#  u'0801',
#  u'0806',
#  u'0844',
#  u'0888',
#  u'09',
#  u'0901',
#  u'0903',
#  u'0905',
#  u'0915',
#  u'0919',
#  u'0932',
#  u'0bama',
#  u'0g2',
#  u'10',
#  u'100',
#  u'1000',
#  u'10014',
#  u'1002',
#  u'100k',
#  u'1011',
#  u'1014',
#  u'102809',
#  u'1030',
#  u'10458',
#  u'1052',
#  u'107',
#  u'1071',
#  u'10_public_opinion_in_perspective_russia',
#  u'10am',
#  u'10pm',
#  u'10s',
#  u'11',
#  u'110',
#  u'1100',
#  u'110509',
#  u'111',
#  u'1111',
#  u'1123',
#  u'112709',
#  u'1140',
#  u'11496993',
#  u'1150',
#  u'116',
#  u'117',
#  u'1178',
#  u'118',
#  u'119',
#  u'11am',
#  u'11c',
#  u'11pm',
#  u'11th',
#  u'12',
#  u'120',
#  u'1200',
#  u'121',
#  u'1212',
#  u'123',
#  u'1230',
#  u'1230pm',
#  u'1234',
#  u'1235',
#  u'1240',
#  u'125',
#  u'125m',
#  u'1265368562294',
#  u'127',
#  u'1279552305',
#  u'12958',
#  u'12968',
#  u'12pm',
#  u'12th',
#  u'13',
#  u'1300',
#  u'1300h',
#  u'1301',
#  u'13214',
#  u'13224',
#  u'133',
#  u'1330',
#  u'135',
#  u'13526',
#  u'136116',
#  u'14',
#  u'1403',
#  u'141',
#  u'1419',
#  u'142888',
#  u'145',
#  u'1467',
#  u'148',
#  u'149',
#  u'14th',
#  u'15',
#  u'150',
#  u'1500',
#  u'151',
#  u'1512',
#  u'1515',
#  u'152nd',
#  u'155',
#  u'157',
#  u'1598',
#  u'15am',
#  u'15pm',
#  u'15th',
#  u'16',
#  u'1600',
#  u'1622',
#  u'167',
#  u'16th',
#  u'17',
#  u'1700',
#  u'1709',
#  u'171',
#  u'1739',
#  u'174',
#  u'175',
#  u'177',
#  u'1775',
#  u'179',
#  u'17th',
#  u'18',
#  u'1801',
#  u'1811',
#  u'1830',
#  u'1847',
#  u'1851',
#  u'1858',
#  u'1860',
#  u'187',
#  u'18th',
#  u'19',
#  u'1900',
#  u'19087',
#  u'1910',
#  u'1919',
#  u'192',
#  u'1924',
#  u'1939',
#  u'1945',
#  u'1954',
#  u'1960',
#  u'1962',
#  u'1963',
#  u'1964',
#  u'1967',
#  u'1970',
#  u'1971',
#  u'1979',
#  u'198',
#  u'1980s',
#  u'1981',
#  u'1982',
#  u'1983',
#  u'1984',
#  u'1987',
#  u'1988',
#  u'1989',
#  u'1990s',
#  u'1991',
#  u'1992',
#  u'1993',
#  u'1994',
#  u'1995',
#  u'1996',
#  u'1998',
#  u'1999',
#  u'19th',
#  u'1a',
#  u'1b',
#  u'1c3',
#  u'1d',
#  u'1davis',
#  u'1dr22',
#  u'1m',
#  u'1monday',
#  u'1pm',
#  u'1st',
#  u'1th',
#  u'20',
#  u'200',
#  u'2000',
#  u'20005',
#  u'2000s',
#  u'2001',
#  u'2002',
#  u'2003',
#  u'20036',
#  u'20037',
#  u'2004',
#  u'2005',
#  u'2006',
#  u'2007',
#  u'2008',
#  u'2009',
#  u'200902473093',
#  u'200902473108',
#  u'20098',
#  u'2010',
#  u'20109',
#  u'2011',
#  u'2012',
#  u'2013',
#  u'2014',
#  u'2015',
#  u'2016',
#  u'202',
#  u'2020',
#  u'2024',
#  u'2025',
#  u'2029',
#  u'2030',
#  u'2035',
#  u'2039',
#  u'2040',
#  u'20439',
#  u'2050',
#  u'20520',
#  u'20522',
#  u'208',
#  u'20am',
#  u'20pm',
#  u'20th',
#  u'21',
#  u'2100',
#  u'2110',
#  u'212',
#  u'2121',
#  u'21309',
#  u'216',
#  u'217',
#  u'2174',
#  u'2180',
#  u'21st',
#  u'22',
#  u'2201',
#  u'221',
#  u'2229',
#  u'223',
#  u'224',
#  u'2245',
#  u'2248',
#  u'225',
#  u'2263951',
#  u'22728',
#  u'22d',
#  u'23',
#  u'230',
#  u'2330',
#  u'2363',
#  u'2372',
#  u'2397997',
#  u'23rd',
#  u'24',
#  u'2401',
#  u'241',
#  u'2419',
#  u'243',
#  u'24th',
#  u'25',
#  u'250',
#  u'251',
#  u'252',
#  u'2566',
#  u'25am',
#  u'25th',
#  u'26',
#  u'26112233',
#  u'2612',
#  u'2632026830',
#  u'2645',
#  u'2649',
#  u'27',
#  u'270',
#  u'276',
#  u'278',
#  u'28',
#  u'282001',
#  u'2848',
#  u'287',
#  u'2873',
#  u'28th',
#  u'29',
#  u'2912',
#  u'2972',
#  u'29th',
#  u'2am',
#  u'2bb',
#  u'2nd',
#  u'2pm',
#  u'2r',
#  u'30',
#  u'300',
#  u'301',
#  u'3014',
#  u'303',
#  u'30308',
#  u'30am',
#  u'30arn',
#  u'30pm',
#  u'30th',
#  u'31',
#  u'310',
#  u'312',
#  u'313',
#  u'315',
#  u'3186',
#  u'31st',
#  u'32',
#  u'320',
#  u'3261',
#  u'32nd',
#  u'33',
#  u'330',
#  u'3321',
#  u'34',
#  u'345',
#  u'3481',
#  u'35',
#  u'36',
#  u'3611',
#  u'37',
#  u'371',
#  u'38',
#  u'3820',
#  u'38203',
#  u'38929',
#  u'39',
#  u'390',
#  u'3anuary',
#  u'3dy5rzw50bg',
#  u'3i',
#  u'3k',
#  u'3n',
#  u'3pm',
#  u'3prn',
#  u'3rd',
#  u'40',
#  u'400',
#  u'401',
#  u'4020',
#  u'404',
#  u'41',
#  u'4120',
#  u'4178',
#  u'42',
#  u'4204',
#  u'422',
#  u'4289',
#  u'429',
#  u'43',
#  u'439',
#  u'44',
#  u'440',
#  u'4443',
#  u'445',
#  u'4451',
#  u'447',
#  u'45',
#  u'4520',
#  u'456',
#  u'45am',
#  u'45pm',
#  u'46',
#  u'4600',
#  u'4636',
#  u'4691',
#  u'47',
#  u'475',
#  u'476',
#  u'47697002',
#  u'48',
#  u'485',
#  u'486',
#  u'49',
#  u'4969',
#  u'49968',
#  u'4am',
#  u'4awiya',
#  u'4bedinh',
#  u'4pm',
#  u'50',
#  u'500',
#  u'5029',
#  u'505',
#  u'509',
#  u'50am',
#  u'50k',
#  u'50th',
#  u'51',
#  u'510',
#  u'512',
#  u'515',
#  u'5173',
#  u'52',
#  u'5240',
#  u'5256',
#  u'527',
#  u'5290',
#  u'53',
#  u'5300',
#  u'5302',
#  u'53pm',
#  u'54',
#  u'540',
#  u'540pm',
#  u'5470',
#  u'55',
#  u'550',
#  u'5508',
#  u'55pam',
#  u'56',
#  u'5600',
#  u'562',
#  u'565',
#  u'57',
#  u'571',
#  u'5723',
#  u'58',
#  u'5855',
#  u'58754',
#  u'59',
#  u'593',
#  u'5932',
#  u'594',
#  u'595',
#  u'596',
#  u'597',
#  u'598',
#  u'599',
#  u'5cb0045096',
#  u'5cb0045248',
#  u'5cb0045459',
#  u'5cb0045650',
#  u'5cb0045653',
#  u'5cb0045671',
#  u'5cb0045672',
#  u'5cb0045673',
#  u'5cb0045674',
#  u'5cb0045675',
#  u'5cb0045676',
#  u'5cb0045677',
#  u'5cb0045678',
#  u'5cb0045679',
#  u'5cb0045680',
#  u'5cb0045681',
#  u'5cb0045682',
#  u'5cb0045683',
#  u'5cb0045684',
#  u'5cb0045685',
#  u'5cb0045799',
#  u'5fm',
#  u'5k',
#  u'5on',
#  u'5pm',
#  u'5th',
#  u'60',
#  u'600',
#  u'601',
#  u'602',
#  u'603',
#  u'604',
#  u'60604',
#  u'60606',
#  u'60610',
#  u'60661',
#  u'61',
#  u'6101',
#  u'613',
#  u'614',
#  u'62',
#  u'6200',
#  u'6240',
#  u'6250',
#  u'63',
#  u'630pm',
#  u'6315',
#  u'6317',
#  u'6323',
#  u'64',
#  u'6421',
#  u'643',
#  u'647',
#  u'65',
#  u'650',
#  u'6607',
#  u'663',
#  u'6676',
#  u'67',
#  u'6727',
#  u'674_225506_9',
#  u'6760',
#  u'68',
#  u'6805',
#  u'687',
#  u'69',
#  u'6am',
#  u'6pm',
#  u'6pr',
#  u'6th',
#  u'70',
#  u'700',
#  u'70064',
#  u'7008',
#  u'702',
#  u'7096',
#  u'7098',
#  u'71',
#  u'711',
#  u'7128',
#  u'717',
#  u'71r',
#  u'7203',
#  u'7209',
#  u'722',
#  u'72204',
#  u'72205',
#  u'7261',
#  u'727',
#  u'7283',
#  u'7288',
#  u'73',
#  u'730',
#  u'7311',
#  u'732',
#  u'736',
#  u'74',
#  u'741',
#  u'7495',
#  u'75',
#  u'7516',
#  u'752',
#  u'7551',
#  u'7555',
#  u'7647',
#  u'77',
#  u'7719',
#  u'7782',
#  u'7869',
#  u'797',
#  u'7994',
#  u'7am',
#  u'7n',
#  u'7pin',
#  u'7pm',
#  u'7prn',
#  u'7th',
#  u'80',
#  u'800',
#  u'8000',
#  u'8100',
#  u'8132',
#  u'813674587',
#  u'815',
#  u'81654',
#  u'819',
#  u'820',
#  u'822',
#  u'830',
#  u'8300',
#  u'84',
#  u'848',
#  u'850',
#  u'8633',
#  u'866',
#  u'8690',
#  u'89',
#  u'8906',
#  u'89092071',
#  u'89092072',
#  u'89092073',
#  u'89092074',
#  u'89092075',
#  u'89092076',
#  u'89092077',
#  u'89092078',
#  u'89092079',
#  u'89092080',
#  u'89092081',
#  u'89092082',
#  u'89092083',
#  u'8am',
#  u'8pm',
#  u'8th',
#  u'8v',
#  u'90',
#  u'900',
#  u'90404',
#  u'906',
#  u'9071',
#  u'90s',
#  u'91',
#  u'9105',
#  u'9111',
#  u'91301',
#  u'914',
#  u'916',
#  u'92',
#  u'928',
#  u'9294',
#  u'93',
#  u'930',
#  u'930am',
#  u'944',
#  u'9533',
#  u'9598',
#  u'9602',
#  u'967',
#  u'98',
#  u'981',
#  u'9842',
#  u'989',
#  u'9995',
#  u'9am',
#  u'9arn',
#  u'9arri',
#  u'9k',
#  u'9pm',
#  u'9th',
#  u'9w',
#  u'_i',
#  u'_juan',
#  u'aa',
#  u'aaj',
#  u'aam',
#  u'aaron',
#  u'aasia',
#  u'ababa',
#  u'abandon',
#  u'abandoned',
#  u'abandonment',
#  u'abbas',
#  u'abbasi',
#  u'abbaszadeh',
#  u'abd',
#  u'abduction',
#  u'abdulkadir',
#  u'abdulla',
#  u'abdullah',
#  u'abe',
#  u'abeclinh',
#  u'abed',
#  u'abedin',
#  u'abedine',
#  u'abedinh',
#  u'abedir',
#  u'abedln',
#  u'abid',
#  u'abide',
#  u'abilities',
#  u'ability',
#  u'abl',
#  u'able',
#  u'aboard',
#  u'abolished',
#  u'abolition',
#  u'abomination',
#  u'abortion',
#  u'abortions',
#  u'aboul',
#  u'about',
#  u'above',
#  u'abraham',
#  u'abramson',
#  u'abroad',
#  u'absence',
#  u'absent',
#  u'absolute',
#  u'absolutely',
#  u'absorb',
#  u'abstentions',
#  u'abstract',
#  u'abstruse',
#  u'abt',
#  u'abu',
#  u'abuse',
#  u'abuses',
#  u'abusing',
#  u'abyei',
#  u'academic',
#  u'academics',
#  u'academy',
#  u'accede',
#  u'acceded',
#  u'accelerated',
#  u'accent',
#  u'accentuates',
#  u'accept',
#  u'acceptable',
#  u'accepted',
#  u'accepting',
#  u'accepts',
#  u'access',
#  u'accessibility',
#  u'accessible',
#  u'accident',
#  u'accion',
#  u'acclaimed',
#  u'accommodating',
#  u'accompanies',
#  u'accompany',
#  u'accompanying',
#  u'accomplish',
#  u'accomplished',
#  u'accomplishment',
#  u'accomplishments',
#  u'accord',
#  u'accordance',
#  u'according',
#  u'accordingly',
#  u'account',
#  u'accountability',
#  u'accountable',
#  u'accounting',
#  u'accounts',
#  u'accredited',
#  u'acct',
#  u'acctld',
#  u'accurate',
#  u'accusations',
#  u'accuse',
#  u'accused',
#  u'accuses',
#  u'accusing',
#  u'acheson',
#  u'achieve',
#  u'achieved',
#  u'achievement',
#  u'achievements',
#  u'achieving',
#  u'ackerman',
#  u'acknowledge',
#  u'acknowledged',
#  u'acknowledgement',
#  u'acknowledgements',
#  u'acknowledges',
#  u'acknowledging',
#  u'aclb',
#  u'aclintonemail',
#  u'acquire',
#  u'acquiring',
#  u'acreage',
#  u'acropolis',
#  u'across',
#  u'act',
#  u'acted',
#  u'acting',
#  u'action',
#  u'action_memo_to_s_on_yeosu_2012_participation_5',
#  u'actionable',
#  u'actionaid',
#  u'actions',
#  u'active',
#  u'actively',
#  u'activist',
#  u'activists',
#  u'activities',
#  u'activity',
#  u'actor',
#  u'actors',
#  u'acts',
#  u'actual',
#  u'actually',
#  u'acute',
#  u'acv',
#  u'ad',
#  u'adam',
#  u'adamant',
#  u'adams',
#  u'adamsds',
#  u'adaptations',
#  u'add',
#  u'added',
#  u'adding',
#  u'addis',
#  u'addition',
#  u'additional',
#  u'additionally',
#  u'additions',
#  u'address',
#  u'addressed',
#  u'addressee',
#  u'addresses',
#  u'addressing',
#  u'adds',
#  u'adele',
#  u'aden',
#  u'adequate',
#  u'adequately',
#  u'ades',
#  u'adjointe',
#  u'adjust',
#  u'adjustments',
#  u'adl',
#  u'adler',
#  u'adlerce',
#  u'admin',
#  u'administered',
#  u'administration',
#  u'administrativa',
#  u'administrative',
#  u'administrator',
#  u'admirable',
#  u'admiral',
#  u'admiration',
#  u'admire',
#  u'admired',
#  u'admires',
#  u'admit',
#  u'admits',
#  u'admitted',
#  u'admitting',
#  u'admonitions',
#  u'adolescent',
#  u'adopt',
#  u'adopted',
#  u'adopting',
#  u'adoption',
#  u'adoptions',
#  u'adores',
#  u'adoring',
#  u'adult',
#  u'adulthood',
#  u'adults',
#  u'advance',
#  u'advanced',
#  u'advancing',
#  u'advantage',
#  u'adventure',
#  u'adventuring',
#  u'adventurous',
#  u'advertised',
#  u'advertising',
#  u'advice',
#  u'advise',
#  u'advised',
#  u'adviser',
#  u'advises',
#  u'advising',
#  u'advisor',
#  u'advisors',
#  u'advisory',
#  u'advocacy',
#  u'advocate',
#  u'advocates',
#  u'advocating',
#  u'aeirig',
#  u'af',
#  u'af1',
#  u'afar',
#  u'afb',
#  u'affable',
#  u'affair',
#  u'affaires',
#  u'affairs',
#  u'affect',
#  u'affected',
#  u'affecting',
#  u'affection',
#  u'affectionately',
#  u'affiliate',
#  u'affiliated',
#  u'affinity',
#  u'affirm',
#  u'affirmed',
#  u'affirms',
#  u'afford',
#  u'affordable',
#  u'affordably',
#  u'afghan',
#  u'afghanistan',
#  u'afghans',
#  u'afonso',
#  u'africa',
#  u'african',
#  u'africans',
#  u'africom',
#  u'afridi',
#  u'afro',
#  u'aft',
#  u'after',
#  u'aftermath',
#  u'afternoon',
#  u'aftershocks',
#  u'afterward',
#  u'aga',
#  u'again',
#  u'against',
#  u'age',
#  u'agence',
#  u'agencies',
#  u'agency',
#  u'agenda',
#  u'agendas',
#  u'ages',
#  u'aggravating',
#  u'aggression',
#  u'aggressive',
#  u'aghanistan',
#  u'ago',
#  u'agoa',
#  u'agra',
#  u'agree',
#  u'agreed',
#  u'agreeing',
#  u'agreement',
#  u'agreements',
#  u'agrees',
#  u'agricultural',
#  u'agriculture',
#  u'agroforester',
#  u'agu',
#  u'ahead',
#  u'ahern',
#  u'ahh',
#  u'ahmadinejad',
#  u'ahmed',
#  u'ahmet',
#  u'ahrocdovl2fsdw1uas5rzw50bgf3lmvkdo',
#  u'ahrocdovl3d3dy5rzw50bgf3lmvkds9kzxbocy9hb',
#  u'ahrocdovl3d3dy5rzw50bgf3lmvkds9kzxbocy9jbg',
#  u'ai',
#  u'aid',
#  u'aide',
#  u'aides',
#  u'aids',
#  u'aig',
#  u'ail',
#  u'aim',
#  u'aimed',
#  u'aiming',
#  u'aini',
#  u'aio',
#  u'aipac',
#  u'air',
#  u'airbase',
#  u'aircraft',
#  u'aired',
#  u'airlift',
#  u'airline',
#  u'airlines',
#  u'airport',
#  u'airports',
#  ...]

# %%
# Create a frequency vectorizer
freq_vect = CountVectorizer(decode_error = 'ignore')
# Call fit to do our frequency vectorization
freq_vect.fit(X_train)
# Check out the dictionary of features
freq_vect.get_feature_names()
# Out:
# [u'00',
#  u'000',
#  u'0000',
#  u'0001',
#  u'001',
#  u'008',
#  u'00am',
#  u'00b',
#  u'00n',
#  u'00pm',
#  u'00v',
#  u'01',
#  u'010000000000',
#  u'0102',
#  u'0105',
#  u'011',
#  u'0129',
#  u'02',
#  u'0203',
#  u'020510',
#  u'021',
#  u'0265',
#  u'0271',
#  u'03',
#  u'0301',
#  u'0308',
#  u'031406z',
#  u'0323',
#  u'0380',
#  u'0390',
#  u'04',
#  u'0400',
#  u'0418',
#  u'04841',
#  u'05',
#  u'0500',
#  u'050710',
#  u'0509',
#  u'0517',
#  u'055',
#  u'05am',
#  u'06',
#  u'0600',
#  u'060209',
#  u'0603',
#  u'0604',
#  u'0605',
#  u'0609',
#  u'062',
#  u'06397276',
#  u'07',
#  u'0710',
#  u'0714',
#  u'0730',
#  u'0745',
#  u'07oct',
#  u'08',
#  u'0801',
#  u'0806',
#  u'0844',
#  u'0888',
#  u'09',
#  u'0901',
#  u'0903',
#  u'0905',
#  u'0915',
#  u'0919',
#  u'0932',
#  u'0bama',
#  u'0g2',
#  u'10',
#  u'100',
#  u'1000',
#  u'10014',
#  u'1002',
#  u'100k',
#  u'1011',
#  u'1014',
#  u'102809',
#  u'1030',
#  u'10458',
#  u'1052',
#  u'107',
#  u'1071',
#  u'10_public_opinion_in_perspective_russia',
#  u'10am',
#  u'10pm',
#  u'10s',
#  u'11',
#  u'110',
#  u'1100',
#  u'110509',
#  u'111',
#  u'1111',
#  u'1123',
#  u'112709',
#  u'1140',
#  u'11496993',
#  u'1150',
#  u'116',
#  u'117',
#  u'1178',
#  u'118',
#  u'119',
#  u'11am',
#  u'11c',
#  u'11pm',
#  u'11th',
#  u'12',
#  u'120',
#  u'1200',
#  u'121',
#  u'1212',
#  u'123',
#  u'1230',
#  u'1230pm',
#  u'1234',
#  u'1235',
#  u'1240',
#  u'125',
#  u'125m',
#  u'1265368562294',
#  u'127',
#  u'1279552305',
#  u'12958',
#  u'12968',
#  u'12pm',
#  u'12th',
#  u'13',
#  u'1300',
#  u'1300h',
#  u'1301',
#  u'13214',
#  u'13224',
#  u'133',
#  u'1330',
#  u'135',
#  u'13526',
#  u'136116',
#  u'14',
#  u'1403',
#  u'141',
#  u'1419',
#  u'142888',
#  u'145',
#  u'1467',
#  u'148',
#  u'149',
#  u'14th',
#  u'15',
#  u'150',
#  u'1500',
#  u'151',
#  u'1512',
#  u'1515',
#  u'152nd',
#  u'155',
#  u'157',
#  u'1598',
#  u'15am',
#  u'15pm',
#  u'15th',
#  u'16',
#  u'1600',
#  u'1622',
#  u'167',
#  u'16th',
#  u'17',
#  u'1700',
#  u'1709',
#  u'171',
#  u'1739',
#  u'174',
#  u'175',
#  u'177',
#  u'1775',
#  u'179',
#  u'17th',
#  u'18',
#  u'1801',
#  u'1811',
#  u'1830',
#  u'1847',
#  u'1851',
#  u'1858',
#  u'1860',
#  u'187',
#  u'18th',
#  u'19',
#  u'1900',
#  u'19087',
#  u'1910',
#  u'1919',
#  u'192',
#  u'1924',
#  u'1939',
#  u'1945',
#  u'1954',
#  u'1960',
#  u'1962',
#  u'1963',
#  u'1964',
#  u'1967',
#  u'1970',
#  u'1971',
#  u'1979',
#  u'198',
#  u'1980s',
#  u'1981',
#  u'1982',
#  u'1983',
#  u'1984',
#  u'1987',
#  u'1988',
#  u'1989',
#  u'1990s',
#  u'1991',
#  u'1992',
#  u'1993',
#  u'1994',
#  u'1995',
#  u'1996',
#  u'1998',
#  u'1999',
#  u'19th',
#  u'1a',
#  u'1b',
#  u'1c3',
#  u'1d',
#  u'1davis',
#  u'1dr22',
#  u'1m',
#  u'1monday',
#  u'1pm',
#  u'1st',
#  u'1th',
#  u'20',
#  u'200',
#  u'2000',
#  u'20005',
#  u'2000s',
#  u'2001',
#  u'2002',
#  u'2003',
#  u'20036',
#  u'20037',
#  u'2004',
#  u'2005',
#  u'2006',
#  u'2007',
#  u'2008',
#  u'2009',
#  u'200902473093',
#  u'200902473108',
#  u'20098',
#  u'2010',
#  u'20109',
#  u'2011',
#  u'2012',
#  u'2013',
#  u'2014',
#  u'2015',
#  u'2016',
#  u'202',
#  u'2020',
#  u'2024',
#  u'2025',
#  u'2029',
#  u'2030',
#  u'2035',
#  u'2039',
#  u'2040',
#  u'20439',
#  u'2050',
#  u'20520',
#  u'20522',
#  u'208',
#  u'20am',
#  u'20pm',
#  u'20th',
#  u'21',
#  u'2100',
#  u'2110',
#  u'212',
#  u'2121',
#  u'21309',
#  u'216',
#  u'217',
#  u'2174',
#  u'2180',
#  u'21st',
#  u'22',
#  u'2201',
#  u'221',
#  u'2229',
#  u'223',
#  u'224',
#  u'2245',
#  u'2248',
#  u'225',
#  u'2263951',
#  u'22728',
#  u'22d',
#  u'23',
#  u'230',
#  u'2330',
#  u'2363',
#  u'2372',
#  u'2397997',
#  u'23rd',
#  u'24',
#  u'2401',
#  u'241',
#  u'2419',
#  u'243',
#  u'24th',
#  u'25',
#  u'250',
#  u'251',
#  u'252',
#  u'2566',
#  u'25am',
#  u'25th',
#  u'26',
#  u'26112233',
#  u'2612',
#  u'2632026830',
#  u'2645',
#  u'2649',
#  u'27',
#  u'270',
#  u'276',
#  u'278',
#  u'28',
#  u'282001',
#  u'2848',
#  u'287',
#  u'2873',
#  u'28th',
#  u'29',
#  u'2912',
#  u'2972',
#  u'29th',
#  u'2am',
#  u'2bb',
#  u'2nd',
#  u'2pm',
#  u'2r',
#  u'30',
#  u'300',
#  u'301',
#  u'3014',
#  u'303',
#  u'30308',
#  u'30am',
#  u'30arn',
#  u'30pm',
#  u'30th',
#  u'31',
#  u'310',
#  u'312',
#  u'313',
#  u'315',
#  u'3186',
#  u'31st',
#  u'32',
#  u'320',
#  u'3261',
#  u'32nd',
#  u'33',
#  u'330',
#  u'3321',
#  u'34',
#  u'345',
#  u'3481',
#  u'35',
#  u'36',
#  u'3611',
#  u'37',
#  u'371',
#  u'38',
#  u'3820',
#  u'38203',
#  u'38929',
#  u'39',
#  u'390',
#  u'3anuary',
#  u'3dy5rzw50bg',
#  u'3i',
#  u'3k',
#  u'3n',
#  u'3pm',
#  u'3prn',
#  u'3rd',
#  u'40',
#  u'400',
#  u'401',
#  u'4020',
#  u'404',
#  u'41',
#  u'4120',
#  u'4178',
#  u'42',
#  u'4204',
#  u'422',
#  u'4289',
#  u'429',
#  u'43',
#  u'439',
#  u'44',
#  u'440',
#  u'4443',
#  u'445',
#  u'4451',
#  u'447',
#  u'45',
#  u'4520',
#  u'456',
#  u'45am',
#  u'45pm',
#  u'46',
#  u'4600',
#  u'4636',
#  u'4691',
#  u'47',
#  u'475',
#  u'476',
#  u'47697002',
#  u'48',
#  u'485',
#  u'486',
#  u'49',
#  u'4969',
#  u'49968',
#  u'4am',
#  u'4awiya',
#  u'4bedinh',
#  u'4pm',
#  u'50',
#  u'500',
#  u'5029',
#  u'505',
#  u'509',
#  u'50am',
#  u'50k',
#  u'50th',
#  u'51',
#  u'510',
#  u'512',
#  u'515',
#  u'5173',
#  u'52',
#  u'5240',
#  u'5256',
#  u'527',
#  u'5290',
#  u'53',
#  u'5300',
#  u'5302',
#  u'53pm',
#  u'54',
#  u'540',
#  u'540pm',
#  u'5470',
#  u'55',
#  u'550',
#  u'5508',
#  u'55pam',
#  u'56',
#  u'5600',
#  u'562',
#  u'565',
#  u'57',
#  u'571',
#  u'5723',
#  u'58',
#  u'5855',
#  u'58754',
#  u'59',
#  u'593',
#  u'5932',
#  u'594',
#  u'595',
#  u'596',
#  u'597',
#  u'598',
#  u'599',
#  u'5cb0045096',
#  u'5cb0045248',
#  u'5cb0045459',
#  u'5cb0045650',
#  u'5cb0045653',
#  u'5cb0045671',
#  u'5cb0045672',
#  u'5cb0045673',
#  u'5cb0045674',
#  u'5cb0045675',
#  u'5cb0045676',
#  u'5cb0045677',
#  u'5cb0045678',
#  u'5cb0045679',
#  u'5cb0045680',
#  u'5cb0045681',
#  u'5cb0045682',
#  u'5cb0045683',
#  u'5cb0045684',
#  u'5cb0045685',
#  u'5cb0045799',
#  u'5fm',
#  u'5k',
#  u'5on',
#  u'5pm',
#  u'5th',
#  u'60',
#  u'600',
#  u'601',
#  u'602',
#  u'603',
#  u'604',
#  u'60604',
#  u'60606',
#  u'60610',
#  u'60661',
#  u'61',
#  u'6101',
#  u'613',
#  u'614',
#  u'62',
#  u'6200',
#  u'6240',
#  u'6250',
#  u'63',
#  u'630pm',
#  u'6315',
#  u'6317',
#  u'6323',
#  u'64',
#  u'6421',
#  u'643',
#  u'647',
#  u'65',
#  u'650',
#  u'6607',
#  u'663',
#  u'6676',
#  u'67',
#  u'6727',
#  u'674_225506_9',
#  u'6760',
#  u'68',
#  u'6805',
#  u'687',
#  u'69',
#  u'6am',
#  u'6pm',
#  u'6pr',
#  u'6th',
#  u'70',
#  u'700',
#  u'70064',
#  u'7008',
#  u'702',
#  u'7096',
#  u'7098',
#  u'71',
#  u'711',
#  u'7128',
#  u'717',
#  u'71r',
#  u'7203',
#  u'7209',
#  u'722',
#  u'72204',
#  u'72205',
#  u'7261',
#  u'727',
#  u'7283',
#  u'7288',
#  u'73',
#  u'730',
#  u'7311',
#  u'732',
#  u'736',
#  u'74',
#  u'741',
#  u'7495',
#  u'75',
#  u'7516',
#  u'752',
#  u'7551',
#  u'7555',
#  u'7647',
#  u'77',
#  u'7719',
#  u'7782',
#  u'7869',
#  u'797',
#  u'7994',
#  u'7am',
#  u'7n',
#  u'7pin',
#  u'7pm',
#  u'7prn',
#  u'7th',
#  u'80',
#  u'800',
#  u'8000',
#  u'8100',
#  u'8132',
#  u'813674587',
#  u'815',
#  u'81654',
#  u'819',
#  u'820',
#  u'822',
#  u'830',
#  u'8300',
#  u'84',
#  u'848',
#  u'850',
#  u'8633',
#  u'866',
#  u'8690',
#  u'89',
#  u'8906',
#  u'89092071',
#  u'89092072',
#  u'89092073',
#  u'89092074',
#  u'89092075',
#  u'89092076',
#  u'89092077',
#  u'89092078',
#  u'89092079',
#  u'89092080',
#  u'89092081',
#  u'89092082',
#  u'89092083',
#  u'8am',
#  u'8pm',
#  u'8th',
#  u'8v',
#  u'90',
#  u'900',
#  u'90404',
#  u'906',
#  u'9071',
#  u'90s',
#  u'91',
#  u'9105',
#  u'9111',
#  u'91301',
#  u'914',
#  u'916',
#  u'92',
#  u'928',
#  u'9294',
#  u'93',
#  u'930',
#  u'930am',
#  u'944',
#  u'9533',
#  u'9598',
#  u'9602',
#  u'967',
#  u'98',
#  u'981',
#  u'9842',
#  u'989',
#  u'9995',
#  u'9am',
#  u'9arn',
#  u'9arri',
#  u'9k',
#  u'9pm',
#  u'9th',
#  u'9w',
#  u'_i',
#  u'_juan',
#  u'aa',
#  u'aaj',
#  u'aam',
#  u'aaron',
#  u'aasia',
#  u'ababa',
#  u'abandon',
#  u'abandoned',
#  u'abandonment',
#  u'abbas',
#  u'abbasi',
#  u'abbaszadeh',
#  u'abd',
#  u'abduction',
#  u'abdulkadir',
#  u'abdulla',
#  u'abdullah',
#  u'abe',
#  u'abeclinh',
#  u'abed',
#  u'abedin',
#  u'abedine',
#  u'abedinh',
#  u'abedir',
#  u'abedln',
#  u'abid',
#  u'abide',
#  u'abilities',
#  u'ability',
#  u'abl',
#  u'able',
#  u'aboard',
#  u'abolished',
#  u'abolition',
#  u'abomination',
#  u'abortion',
#  u'abortions',
#  u'aboul',
#  u'about',
#  u'above',
#  u'abraham',
#  u'abramson',
#  u'abroad',
#  u'absence',
#  u'absent',
#  u'absolute',
#  u'absolutely',
#  u'absorb',
#  u'abstentions',
#  u'abstract',
#  u'abstruse',
#  u'abt',
#  u'abu',
#  u'abuse',
#  u'abuses',
#  u'abusing',
#  u'abyei',
#  u'academic',
#  u'academics',
#  u'academy',
#  u'accede',
#  u'acceded',
#  u'accelerated',
#  u'accent',
#  u'accentuates',
#  u'accept',
#  u'acceptable',
#  u'accepted',
#  u'accepting',
#  u'accepts',
#  u'access',
#  u'accessibility',
#  u'accessible',
#  u'accident',
#  u'accion',
#  u'acclaimed',
#  u'accommodating',
#  u'accompanies',
#  u'accompany',
#  u'accompanying',
#  u'accomplish',
#  u'accomplished',
#  u'accomplishment',
#  u'accomplishments',
#  u'accord',
#  u'accordance',
#  u'according',
#  u'accordingly',
#  u'account',
#  u'accountability',
#  u'accountable',
#  u'accounting',
#  u'accounts',
#  u'accredited',
#  u'acct',
#  u'acctld',
#  u'accurate',
#  u'accusations',
#  u'accuse',
#  u'accused',
#  u'accuses',
#  u'accusing',
#  u'acheson',
#  u'achieve',
#  u'achieved',
#  u'achievement',
#  u'achievements',
#  u'achieving',
#  u'ackerman',
#  u'acknowledge',
#  u'acknowledged',
#  u'acknowledgement',
#  u'acknowledgements',
#  u'acknowledges',
#  u'acknowledging',
#  u'aclb',
#  u'aclintonemail',
#  u'acquire',
#  u'acquiring',
#  u'acreage',
#  u'acropolis',
#  u'across',
#  u'act',
#  u'acted',
#  u'acting',
#  u'action',
#  u'action_memo_to_s_on_yeosu_2012_participation_5',
#  u'actionable',
#  u'actionaid',
#  u'actions',
#  u'active',
#  u'actively',
#  u'activist',
#  u'activists',
#  u'activities',
#  u'activity',
#  u'actor',
#  u'actors',
#  u'acts',
#  u'actual',
#  u'actually',
#  u'acute',
#  u'acv',
#  u'ad',
#  u'adam',
#  u'adamant',
#  u'adams',
#  u'adamsds',
#  u'adaptations',
#  u'add',
#  u'added',
#  u'adding',
#  u'addis',
#  u'addition',
#  u'additional',
#  u'additionally',
#  u'additions',
#  u'address',
#  u'addressed',
#  u'addressee',
#  u'addresses',
#  u'addressing',
#  u'adds',
#  u'adele',
#  u'aden',
#  u'adequate',
#  u'adequately',
#  u'ades',
#  u'adjointe',
#  u'adjust',
#  u'adjustments',
#  u'adl',
#  u'adler',
#  u'adlerce',
#  u'admin',
#  u'administered',
#  u'administration',
#  u'administrativa',
#  u'administrative',
#  u'administrator',
#  u'admirable',
#  u'admiral',
#  u'admiration',
#  u'admire',
#  u'admired',
#  u'admires',
#  u'admit',
#  u'admits',
#  u'admitted',
#  u'admitting',
#  u'admonitions',
#  u'adolescent',
#  u'adopt',
#  u'adopted',
#  u'adopting',
#  u'adoption',
#  u'adoptions',
#  u'adores',
#  u'adoring',
#  u'adult',
#  u'adulthood',
#  u'adults',
#  u'advance',
#  u'advanced',
#  u'advancing',
#  u'advantage',
#  u'adventure',
#  u'adventuring',
#  u'adventurous',
#  u'advertised',
#  u'advertising',
#  u'advice',
#  u'advise',
#  u'advised',
#  u'adviser',
#  u'advises',
#  u'advising',
#  u'advisor',
#  u'advisors',
#  u'advisory',
#  u'advocacy',
#  u'advocate',
#  u'advocates',
#  u'advocating',
#  u'aeirig',
#  u'af',
#  u'af1',
#  u'afar',
#  u'afb',
#  u'affable',
#  u'affair',
#  u'affaires',
#  u'affairs',
#  u'affect',
#  u'affected',
#  u'affecting',
#  u'affection',
#  u'affectionately',
#  u'affiliate',
#  u'affiliated',
#  u'affinity',
#  u'affirm',
#  u'affirmed',
#  u'affirms',
#  u'afford',
#  u'affordable',
#  u'affordably',
#  u'afghan',
#  u'afghanistan',
#  u'afghans',
#  u'afonso',
#  u'africa',
#  u'african',
#  u'africans',
#  u'africom',
#  u'afridi',
#  u'afro',
#  u'aft',
#  u'after',
#  u'aftermath',
#  u'afternoon',
#  u'aftershocks',
#  u'afterward',
#  u'aga',
#  u'again',
#  u'against',
#  u'age',
#  u'agence',
#  u'agencies',
#  u'agency',
#  u'agenda',
#  u'agendas',
#  u'ages',
#  u'aggravating',
#  u'aggression',
#  u'aggressive',
#  u'aghanistan',
#  u'ago',
#  u'agoa',
#  u'agra',
#  u'agree',
#  u'agreed',
#  u'agreeing',
#  u'agreement',
#  u'agreements',
#  u'agrees',
#  u'agricultural',
#  u'agriculture',
#  u'agroforester',
#  u'agu',
#  u'ahead',
#  u'ahern',
#  u'ahh',
#  u'ahmadinejad',
#  u'ahmed',
#  u'ahmet',
#  u'ahrocdovl2fsdw1uas5rzw50bgf3lmvkdo',
#  u'ahrocdovl3d3dy5rzw50bgf3lmvkds9kzxbocy9hb',
#  u'ahrocdovl3d3dy5rzw50bgf3lmvkds9kzxbocy9jbg',
#  u'ai',
#  u'aid',
#  u'aide',
#  u'aides',
#  u'aids',
#  u'aig',
#  u'ail',
#  u'aim',
#  u'aimed',
#  u'aiming',
#  u'aini',
#  u'aio',
#  u'aipac',
#  u'air',
#  u'airbase',
#  u'aircraft',
#  u'aired',
#  u'airlift',
#  u'airline',
#  u'airlines',
#  u'airport',
#  u'airports',
#  ...]

# %%
# Import TfidfVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
# Create a TFIDF vectorizer
tfidf_vect = TfidfVectorizer(decode_error = 'ignore')
# Call fit to do our frequency vectorization
tfidf_vect.fit(X_train)
# Check out the dictionary of features
tfidf_vect.get_feature_names()
# Out:
# [u'00',
#  u'000',
#  u'0000',
#  u'0001',
#  u'001',
#  u'008',
#  u'00am',
#  u'00b',
#  u'00n',
#  u'00pm',
#  u'00v',
#  u'01',
#  u'010000000000',
#  u'0102',
#  u'0105',
#  u'011',
#  u'0129',
#  u'02',
#  u'0203',
#  u'020510',
#  u'021',
#  u'0265',
#  u'0271',
#  u'03',
#  u'0301',
#  u'0308',
#  u'031406z',
#  u'0323',
#  u'0380',
#  u'0390',
#  u'04',
#  u'0400',
#  u'0418',
#  u'04841',
#  u'05',
#  u'0500',
#  u'050710',
#  u'0509',
#  u'0517',
#  u'055',
#  u'05am',
#  u'06',
#  u'0600',
#  u'060209',
#  u'0603',
#  u'0604',
#  u'0605',
#  u'0609',
#  u'062',
#  u'06397276',
#  u'07',
#  u'0710',
#  u'0714',
#  u'0730',
#  u'0745',
#  u'07oct',
#  u'08',
#  u'0801',
#  u'0806',
#  u'0844',
#  u'0888',
#  u'09',
#  u'0901',
#  u'0903',
#  u'0905',
#  u'0915',
#  u'0919',
#  u'0932',
#  u'0bama',
#  u'0g2',
#  u'10',
#  u'100',
#  u'1000',
#  u'10014',
#  u'1002',
#  u'100k',
#  u'1011',
#  u'1014',
#  u'102809',
#  u'1030',
#  u'10458',
#  u'1052',
#  u'107',
#  u'1071',
#  u'10_public_opinion_in_perspective_russia',
#  u'10am',
#  u'10pm',
#  u'10s',
#  u'11',
#  u'110',
#  u'1100',
#  u'110509',
#  u'111',
#  u'1111',
#  u'1123',
#  u'112709',
#  u'1140',
#  u'11496993',
#  u'1150',
#  u'116',
#  u'117',
#  u'1178',
#  u'118',
#  u'119',
#  u'11am',
#  u'11c',
#  u'11pm',
#  u'11th',
#  u'12',
#  u'120',
#  u'1200',
#  u'121',
#  u'1212',
#  u'123',
#  u'1230',
#  u'1230pm',
#  u'1234',
#  u'1235',
#  u'1240',
#  u'125',
#  u'125m',
#  u'1265368562294',
#  u'127',
#  u'1279552305',
#  u'12958',
#  u'12968',
#  u'12pm',
#  u'12th',
#  u'13',
#  u'1300',
#  u'1300h',
#  u'1301',
#  u'13214',
#  u'13224',
#  u'133',
#  u'1330',
#  u'135',
#  u'13526',
#  u'136116',
#  u'14',
#  u'1403',
#  u'141',
#  u'1419',
#  u'142888',
#  u'145',
#  u'1467',
#  u'148',
#  u'149',
#  u'14th',
#  u'15',
#  u'150',
#  u'1500',
#  u'151',
#  u'1512',
#  u'1515',
#  u'152nd',
#  u'155',
#  u'157',
#  u'1598',
#  u'15am',
#  u'15pm',
#  u'15th',
#  u'16',
#  u'1600',
#  u'1622',
#  u'167',
#  u'16th',
#  u'17',
#  u'1700',
#  u'1709',
#  u'171',
#  u'1739',
#  u'174',
#  u'175',
#  u'177',
#  u'1775',
#  u'179',
#  u'17th',
#  u'18',
#  u'1801',
#  u'1811',
#  u'1830',
#  u'1847',
#  u'1851',
#  u'1858',
#  u'1860',
#  u'187',
#  u'18th',
#  u'19',
#  u'1900',
#  u'19087',
#  u'1910',
#  u'1919',
#  u'192',
#  u'1924',
#  u'1939',
#  u'1945',
#  u'1954',
#  u'1960',
#  u'1962',
#  u'1963',
#  u'1964',
#  u'1967',
#  u'1970',
#  u'1971',
#  u'1979',
#  u'198',
#  u'1980s',
#  u'1981',
#  u'1982',
#  u'1983',
#  u'1984',
#  u'1987',
#  u'1988',
#  u'1989',
#  u'1990s',
#  u'1991',
#  u'1992',
#  u'1993',
#  u'1994',
#  u'1995',
#  u'1996',
#  u'1998',
#  u'1999',
#  u'19th',
#  u'1a',
#  u'1b',
#  u'1c3',
#  u'1d',
#  u'1davis',
#  u'1dr22',
#  u'1m',
#  u'1monday',
#  u'1pm',
#  u'1st',
#  u'1th',
#  u'20',
#  u'200',
#  u'2000',
#  u'20005',
#  u'2000s',
#  u'2001',
#  u'2002',
#  u'2003',
#  u'20036',
#  u'20037',
#  u'2004',
#  u'2005',
#  u'2006',
#  u'2007',
#  u'2008',
#  u'2009',
#  u'200902473093',
#  u'200902473108',
#  u'20098',
#  u'2010',
#  u'20109',
#  u'2011',
#  u'2012',
#  u'2013',
#  u'2014',
#  u'2015',
#  u'2016',
#  u'202',
#  u'2020',
#  u'2024',
#  u'2025',
#  u'2029',
#  u'2030',
#  u'2035',
#  u'2039',
#  u'2040',
#  u'20439',
#  u'2050',
#  u'20520',
#  u'20522',
#  u'208',
#  u'20am',
#  u'20pm',
#  u'20th',
#  u'21',
#  u'2100',
#  u'2110',
#  u'212',
#  u'2121',
#  u'21309',
#  u'216',
#  u'217',
#  u'2174',
#  u'2180',
#  u'21st',
#  u'22',
#  u'2201',
#  u'221',
#  u'2229',
#  u'223',
#  u'224',
#  u'2245',
#  u'2248',
#  u'225',
#  u'2263951',
#  u'22728',
#  u'22d',
#  u'23',
#  u'230',
#  u'2330',
#  u'2363',
#  u'2372',
#  u'2397997',
#  u'23rd',
#  u'24',
#  u'2401',
#  u'241',
#  u'2419',
#  u'243',
#  u'24th',
#  u'25',
#  u'250',
#  u'251',
#  u'252',
#  u'2566',
#  u'25am',
#  u'25th',
#  u'26',
#  u'26112233',
#  u'2612',
#  u'2632026830',
#  u'2645',
#  u'2649',
#  u'27',
#  u'270',
#  u'276',
#  u'278',
#  u'28',
#  u'282001',
#  u'2848',
#  u'287',
#  u'2873',
#  u'28th',
#  u'29',
#  u'2912',
#  u'2972',
#  u'29th',
#  u'2am',
#  u'2bb',
#  u'2nd',
#  u'2pm',
#  u'2r',
#  u'30',
#  u'300',
#  u'301',
#  u'3014',
#  u'303',
#  u'30308',
#  u'30am',
#  u'30arn',
#  u'30pm',
#  u'30th',
#  u'31',
#  u'310',
#  u'312',
#  u'313',
#  u'315',
#  u'3186',
#  u'31st',
#  u'32',
#  u'320',
#  u'3261',
#  u'32nd',
#  u'33',
#  u'330',
#  u'3321',
#  u'34',
#  u'345',
#  u'3481',
#  u'35',
#  u'36',
#  u'3611',
#  u'37',
#  u'371',
#  u'38',
#  u'3820',
#  u'38203',
#  u'38929',
#  u'39',
#  u'390',
#  u'3anuary',
#  u'3dy5rzw50bg',
#  u'3i',
#  u'3k',
#  u'3n',
#  u'3pm',
#  u'3prn',
#  u'3rd',
#  u'40',
#  u'400',
#  u'401',
#  u'4020',
#  u'404',
#  u'41',
#  u'4120',
#  u'4178',
#  u'42',
#  u'4204',
#  u'422',
#  u'4289',
#  u'429',
#  u'43',
#  u'439',
#  u'44',
#  u'440',
#  u'4443',
#  u'445',
#  u'4451',
#  u'447',
#  u'45',
#  u'4520',
#  u'456',
#  u'45am',
#  u'45pm',
#  u'46',
#  u'4600',
#  u'4636',
#  u'4691',
#  u'47',
#  u'475',
#  u'476',
#  u'47697002',
#  u'48',
#  u'485',
#  u'486',
#  u'49',
#  u'4969',
#  u'49968',
#  u'4am',
#  u'4awiya',
#  u'4bedinh',
#  u'4pm',
#  u'50',
#  u'500',
#  u'5029',
#  u'505',
#  u'509',
#  u'50am',
#  u'50k',
#  u'50th',
#  u'51',
#  u'510',
#  u'512',
#  u'515',
#  u'5173',
#  u'52',
#  u'5240',
#  u'5256',
#  u'527',
#  u'5290',
#  u'53',
#  u'5300',
#  u'5302',
#  u'53pm',
#  u'54',
#  u'540',
#  u'540pm',
#  u'5470',
#  u'55',
#  u'550',
#  u'5508',
#  u'55pam',
#  u'56',
#  u'5600',
#  u'562',
#  u'565',
#  u'57',
#  u'571',
#  u'5723',
#  u'58',
#  u'5855',
#  u'58754',
#  u'59',
#  u'593',
#  u'5932',
#  u'594',
#  u'595',
#  u'596',
#  u'597',
#  u'598',
#  u'599',
#  u'5cb0045096',
#  u'5cb0045248',
#  u'5cb0045459',
#  u'5cb0045650',
#  u'5cb0045653',
#  u'5cb0045671',
#  u'5cb0045672',
#  u'5cb0045673',
#  u'5cb0045674',
#  u'5cb0045675',
#  u'5cb0045676',
#  u'5cb0045677',
#  u'5cb0045678',
#  u'5cb0045679',
#  u'5cb0045680',
#  u'5cb0045681',
#  u'5cb0045682',
#  u'5cb0045683',
#  u'5cb0045684',
#  u'5cb0045685',
#  u'5cb0045799',
#  u'5fm',
#  u'5k',
#  u'5on',
#  u'5pm',
#  u'5th',
#  u'60',
#  u'600',
#  u'601',
#  u'602',
#  u'603',
#  u'604',
#  u'60604',
#  u'60606',
#  u'60610',
#  u'60661',
#  u'61',
#  u'6101',
#  u'613',
#  u'614',
#  u'62',
#  u'6200',
#  u'6240',
#  u'6250',
#  u'63',
#  u'630pm',
#  u'6315',
#  u'6317',
#  u'6323',
#  u'64',
#  u'6421',
#  u'643',
#  u'647',
#  u'65',
#  u'650',
#  u'6607',
#  u'663',
#  u'6676',
#  u'67',
#  u'6727',
#  u'674_225506_9',
#  u'6760',
#  u'68',
#  u'6805',
#  u'687',
#  u'69',
#  u'6am',
#  u'6pm',
#  u'6pr',
#  u'6th',
#  u'70',
#  u'700',
#  u'70064',
#  u'7008',
#  u'702',
#  u'7096',
#  u'7098',
#  u'71',
#  u'711',
#  u'7128',
#  u'717',
#  u'71r',
#  u'7203',
#  u'7209',
#  u'722',
#  u'72204',
#  u'72205',
#  u'7261',
#  u'727',
#  u'7283',
#  u'7288',
#  u'73',
#  u'730',
#  u'7311',
#  u'732',
#  u'736',
#  u'74',
#  u'741',
#  u'7495',
#  u'75',
#  u'7516',
#  u'752',
#  u'7551',
#  u'7555',
#  u'7647',
#  u'77',
#  u'7719',
#  u'7782',
#  u'7869',
#  u'797',
#  u'7994',
#  u'7am',
#  u'7n',
#  u'7pin',
#  u'7pm',
#  u'7prn',
#  u'7th',
#  u'80',
#  u'800',
#  u'8000',
#  u'8100',
#  u'8132',
#  u'813674587',
#  u'815',
#  u'81654',
#  u'819',
#  u'820',
#  u'822',
#  u'830',
#  u'8300',
#  u'84',
#  u'848',
#  u'850',
#  u'8633',
#  u'866',
#  u'8690',
#  u'89',
#  u'8906',
#  u'89092071',
#  u'89092072',
#  u'89092073',
#  u'89092074',
#  u'89092075',
#  u'89092076',
#  u'89092077',
#  u'89092078',
#  u'89092079',
#  u'89092080',
#  u'89092081',
#  u'89092082',
#  u'89092083',
#  u'8am',
#  u'8pm',
#  u'8th',
#  u'8v',
#  u'90',
#  u'900',
#  u'90404',
#  u'906',
#  u'9071',
#  u'90s',
#  u'91',
#  u'9105',
#  u'9111',
#  u'91301',
#  u'914',
#  u'916',
#  u'92',
#  u'928',
#  u'9294',
#  u'93',
#  u'930',
#  u'930am',
#  u'944',
#  u'9533',
#  u'9598',
#  u'9602',
#  u'967',
#  u'98',
#  u'981',
#  u'9842',
#  u'989',
#  u'9995',
#  u'9am',
#  u'9arn',
#  u'9arri',
#  u'9k',
#  u'9pm',
#  u'9th',
#  u'9w',
#  u'_i',
#  u'_juan',
#  u'aa',
#  u'aaj',
#  u'aam',
#  u'aaron',
#  u'aasia',
#  u'ababa',
#  u'abandon',
#  u'abandoned',
#  u'abandonment',
#  u'abbas',
#  u'abbasi',
#  u'abbaszadeh',
#  u'abd',
#  u'abduction',
#  u'abdulkadir',
#  u'abdulla',
#  u'abdullah',
#  u'abe',
#  u'abeclinh',
#  u'abed',
#  u'abedin',
#  u'abedine',
#  u'abedinh',
#  u'abedir',
#  u'abedln',
#  u'abid',
#  u'abide',
#  u'abilities',
#  u'ability',
#  u'abl',
#  u'able',
#  u'aboard',
#  u'abolished',
#  u'abolition',
#  u'abomination',
#  u'abortion',
#  u'abortions',
#  u'aboul',
#  u'about',
#  u'above',
#  u'abraham',
#  u'abramson',
#  u'abroad',
#  u'absence',
#  u'absent',
#  u'absolute',
#  u'absolutely',
#  u'absorb',
#  u'abstentions',
#  u'abstract',
#  u'abstruse',
#  u'abt',
#  u'abu',
#  u'abuse',
#  u'abuses',
#  u'abusing',
#  u'abyei',
#  u'academic',
#  u'academics',
#  u'academy',
#  u'accede',
#  u'acceded',
#  u'accelerated',
#  u'accent',
#  u'accentuates',
#  u'accept',
#  u'acceptable',
#  u'accepted',
#  u'accepting',
#  u'accepts',
#  u'access',
#  u'accessibility',
#  u'accessible',
#  u'accident',
#  u'accion',
#  u'acclaimed',
#  u'accommodating',
#  u'accompanies',
#  u'accompany',
#  u'accompanying',
#  u'accomplish',
#  u'accomplished',
#  u'accomplishment',
#  u'accomplishments',
#  u'accord',
#  u'accordance',
#  u'according',
#  u'accordingly',
#  u'account',
#  u'accountability',
#  u'accountable',
#  u'accounting',
#  u'accounts',
#  u'accredited',
#  u'acct',
#  u'acctld',
#  u'accurate',
#  u'accusations',
#  u'accuse',
#  u'accused',
#  u'accuses',
#  u'accusing',
#  u'acheson',
#  u'achieve',
#  u'achieved',
#  u'achievement',
#  u'achievements',
#  u'achieving',
#  u'ackerman',
#  u'acknowledge',
#  u'acknowledged',
#  u'acknowledgement',
#  u'acknowledgements',
#  u'acknowledges',
#  u'acknowledging',
#  u'aclb',
#  u'aclintonemail',
#  u'acquire',
#  u'acquiring',
#  u'acreage',
#  u'acropolis',
#  u'across',
#  u'act',
#  u'acted',
#  u'acting',
#  u'action',
#  u'action_memo_to_s_on_yeosu_2012_participation_5',
#  u'actionable',
#  u'actionaid',
#  u'actions',
#  u'active',
#  u'actively',
#  u'activist',
#  u'activists',
#  u'activities',
#  u'activity',
#  u'actor',
#  u'actors',
#  u'acts',
#  u'actual',
#  u'actually',
#  u'acute',
#  u'acv',
#  u'ad',
#  u'adam',
#  u'adamant',
#  u'adams',
#  u'adamsds',
#  u'adaptations',
#  u'add',
#  u'added',
#  u'adding',
#  u'addis',
#  u'addition',
#  u'additional',
#  u'additionally',
#  u'additions',
#  u'address',
#  u'addressed',
#  u'addressee',
#  u'addresses',
#  u'addressing',
#  u'adds',
#  u'adele',
#  u'aden',
#  u'adequate',
#  u'adequately',
#  u'ades',
#  u'adjointe',
#  u'adjust',
#  u'adjustments',
#  u'adl',
#  u'adler',
#  u'adlerce',
#  u'admin',
#  u'administered',
#  u'administration',
#  u'administrativa',
#  u'administrative',
#  u'administrator',
#  u'admirable',
#  u'admiral',
#  u'admiration',
#  u'admire',
#  u'admired',
#  u'admires',
#  u'admit',
#  u'admits',
#  u'admitted',
#  u'admitting',
#  u'admonitions',
#  u'adolescent',
#  u'adopt',
#  u'adopted',
#  u'adopting',
#  u'adoption',
#  u'adoptions',
#  u'adores',
#  u'adoring',
#  u'adult',
#  u'adulthood',
#  u'adults',
#  u'advance',
#  u'advanced',
#  u'advancing',
#  u'advantage',
#  u'adventure',
#  u'adventuring',
#  u'adventurous',
#  u'advertised',
#  u'advertising',
#  u'advice',
#  u'advise',
#  u'advised',
#  u'adviser',
#  u'advises',
#  u'advising',
#  u'advisor',
#  u'advisors',
#  u'advisory',
#  u'advocacy',
#  u'advocate',
#  u'advocates',
#  u'advocating',
#  u'aeirig',
#  u'af',
#  u'af1',
#  u'afar',
#  u'afb',
#  u'affable',
#  u'affair',
#  u'affaires',
#  u'affairs',
#  u'affect',
#  u'affected',
#  u'affecting',
#  u'affection',
#  u'affectionately',
#  u'affiliate',
#  u'affiliated',
#  u'affinity',
#  u'affirm',
#  u'affirmed',
#  u'affirms',
#  u'afford',
#  u'affordable',
#  u'affordably',
#  u'afghan',
#  u'afghanistan',
#  u'afghans',
#  u'afonso',
#  u'africa',
#  u'african',
#  u'africans',
#  u'africom',
#  u'afridi',
#  u'afro',
#  u'aft',
#  u'after',
#  u'aftermath',
#  u'afternoon',
#  u'aftershocks',
#  u'afterward',
#  u'aga',
#  u'again',
#  u'against',
#  u'age',
#  u'agence',
#  u'agencies',
#  u'agency',
#  u'agenda',
#  u'agendas',
#  u'ages',
#  u'aggravating',
#  u'aggression',
#  u'aggressive',
#  u'aghanistan',
#  u'ago',
#  u'agoa',
#  u'agra',
#  u'agree',
#  u'agreed',
#  u'agreeing',
#  u'agreement',
#  u'agreements',
#  u'agrees',
#  u'agricultural',
#  u'agriculture',
#  u'agroforester',
#  u'agu',
#  u'ahead',
#  u'ahern',
#  u'ahh',
#  u'ahmadinejad',
#  u'ahmed',
#  u'ahmet',
#  u'ahrocdovl2fsdw1uas5rzw50bgf3lmvkdo',
#  u'ahrocdovl3d3dy5rzw50bgf3lmvkds9kzxbocy9hb',
#  u'ahrocdovl3d3dy5rzw50bgf3lmvkds9kzxbocy9jbg',
#  u'ai',
#  u'aid',
#  u'aide',
#  u'aides',
#  u'aids',
#  u'aig',
#  u'ail',
#  u'aim',
#  u'aimed',
#  u'aiming',
#  u'aini',
#  u'aio',
#  u'aipac',
#  u'air',
#  u'airbase',
#  u'aircraft',
#  u'aired',
#  u'airlift',
#  u'airline',
#  u'airlines',
#  u'airport',
#  u'airports',
#  ...]

# %%
# For the binary model, training and test X matrices
binary_train_dtm = binary_vect.transform(X_train)
binary_test_dtm = binary_vect.transform(X_test)
# For the frequency model, training and test X matrices
freq_train_dtm = freq_vect.transform(X_train)
freq_test_dtm = freq_vect.transform(X_test)
# For the tfidf model, training and test X matrices
tfidf_train_dtm = tfidf_vect.transform(X_train)
tfidf_test_dtm = tfidf_vect.transform(X_test)

# %%
# Import
from sklearn.naive_bayes import MultinomialNB
# Create the model
mnb = MultinomialNB()
# Fit the model to the training data
mnb.fit(freq_train_dtm, y_train)
# Score the model against the test data
mnb.score(freq_test_dtm, y_test)
# Out:
# 0.5714285714285714

# %%
# Create the model
tfidf_nb = MultinomialNB()
# Fit the model to our training data
tfidf_nb.fit(tfidf_train_dtm, y_train)
# Score the model against our test data
tfidf_nb.score(tfidf_test_dtm, y_test)
# Out:
# 0.57875457875457881

# %%
# Import metrics
from sklearn import metrics
# Make class predictions for all observations in the test set
y_pred = mnb.predict(freq_test_dtm)
# Print classification accuracy
metrics.accuracy_score(y_pred, y_test)
# Out:
# 0.5714285714285714

# %%
# Import CountVectorizer
from sklearn.feature_extraction.text import CountVectorizer
# instantiate the vectorizer ( use variable name as vect)
vect = CountVectorizer(decode_error = 'ignore')
# Fit the vectorizer to the training set X_train
vect.fit(X_train)
# Print out the dictionary of terms with get_feature_names()
vect.get_feature_names()
# Out:
# [u'00',
#  u'000',
#  u'0000',
#  u'0001',
#  u'001',
#  u'008',
#  u'00am',
#  u'00b',
#  u'00n',
#  u'00pm',
#  u'00v',
#  u'01',
#  u'010000000000',
#  u'0102',
#  u'0105',
#  u'011',
#  u'0129',
#  u'02',
#  u'0203',
#  u'020510',
#  u'021',
#  u'0265',
#  u'0271',
#  u'03',
#  u'0301',
#  u'0308',
#  u'031406z',
#  u'0323',
#  u'0380',
#  u'0390',
#  u'04',
#  u'0400',
#  u'0418',
#  u'04841',
#  u'05',
#  u'0500',
#  u'050710',
#  u'0509',
#  u'0517',
#  u'055',
#  u'05am',
#  u'06',
#  u'0600',
#  u'060209',
#  u'0603',
#  u'0604',
#  u'0605',
#  u'0609',
#  u'062',
#  u'06397276',
#  u'07',
#  u'0710',
#  u'0714',
#  u'0730',
#  u'0745',
#  u'07oct',
#  u'08',
#  u'0801',
#  u'0806',
#  u'0844',
#  u'0888',
#  u'09',
#  u'0901',
#  u'0903',
#  u'0905',
#  u'0915',
#  u'0919',
#  u'0932',
#  u'0bama',
#  u'0g2',
#  u'10',
#  u'100',
#  u'1000',
#  u'10014',
#  u'1002',
#  u'100k',
#  u'1011',
#  u'1014',
#  u'102809',
#  u'1030',
#  u'10458',
#  u'1052',
#  u'107',
#  u'1071',
#  u'10_public_opinion_in_perspective_russia',
#  u'10am',
#  u'10pm',
#  u'10s',
#  u'11',
#  u'110',
#  u'1100',
#  u'110509',
#  u'111',
#  u'1111',
#  u'1123',
#  u'112709',
#  u'1140',
#  u'11496993',
#  u'1150',
#  u'116',
#  u'117',
#  u'1178',
#  u'118',
#  u'119',
#  u'11am',
#  u'11c',
#  u'11pm',
#  u'11th',
#  u'12',
#  u'120',
#  u'1200',
#  u'121',
#  u'1212',
#  u'123',
#  u'1230',
#  u'1230pm',
#  u'1234',
#  u'1235',
#  u'1240',
#  u'125',
#  u'125m',
#  u'1265368562294',
#  u'127',
#  u'1279552305',
#  u'12958',
#  u'12968',
#  u'12pm',
#  u'12th',
#  u'13',
#  u'1300',
#  u'1300h',
#  u'1301',
#  u'13214',
#  u'13224',
#  u'133',
#  u'1330',
#  u'135',
#  u'13526',
#  u'136116',
#  u'14',
#  u'1403',
#  u'141',
#  u'1419',
#  u'142888',
#  u'145',
#  u'1467',
#  u'148',
#  u'149',
#  u'14th',
#  u'15',
#  u'150',
#  u'1500',
#  u'151',
#  u'1512',
#  u'1515',
#  u'152nd',
#  u'155',
#  u'157',
#  u'1598',
#  u'15am',
#  u'15pm',
#  u'15th',
#  u'16',
#  u'1600',
#  u'1622',
#  u'167',
#  u'16th',
#  u'17',
#  u'1700',
#  u'1709',
#  u'171',
#  u'1739',
#  u'174',
#  u'175',
#  u'177',
#  u'1775',
#  u'179',
#  u'17th',
#  u'18',
#  u'1801',
#  u'1811',
#  u'1830',
#  u'1847',
#  u'1851',
#  u'1858',
#  u'1860',
#  u'187',
#  u'18th',
#  u'19',
#  u'1900',
#  u'19087',
#  u'1910',
#  u'1919',
#  u'192',
#  u'1924',
#  u'1939',
#  u'1945',
#  u'1954',
#  u'1960',
#  u'1962',
#  u'1963',
#  u'1964',
#  u'1967',
#  u'1970',
#  u'1971',
#  u'1979',
#  u'198',
#  u'1980s',
#  u'1981',
#  u'1982',
#  u'1983',
#  u'1984',
#  u'1987',
#  u'1988',
#  u'1989',
#  u'1990s',
#  u'1991',
#  u'1992',
#  u'1993',
#  u'1994',
#  u'1995',
#  u'1996',
#  u'1998',
#  u'1999',
#  u'19th',
#  u'1a',
#  u'1b',
#  u'1c3',
#  u'1d',
#  u'1davis',
#  u'1dr22',
#  u'1m',
#  u'1monday',
#  u'1pm',
#  u'1st',
#  u'1th',
#  u'20',
#  u'200',
#  u'2000',
#  u'20005',
#  u'2000s',
#  u'2001',
#  u'2002',
#  u'2003',
#  u'20036',
#  u'20037',
#  u'2004',
#  u'2005',
#  u'2006',
#  u'2007',
#  u'2008',
#  u'2009',
#  u'200902473093',
#  u'200902473108',
#  u'20098',
#  u'2010',
#  u'20109',
#  u'2011',
#  u'2012',
#  u'2013',
#  u'2014',
#  u'2015',
#  u'2016',
#  u'202',
#  u'2020',
#  u'2024',
#  u'2025',
#  u'2029',
#  u'2030',
#  u'2035',
#  u'2039',
#  u'2040',
#  u'20439',
#  u'2050',
#  u'20520',
#  u'20522',
#  u'208',
#  u'20am',
#  u'20pm',
#  u'20th',
#  u'21',
#  u'2100',
#  u'2110',
#  u'212',
#  u'2121',
#  u'21309',
#  u'216',
#  u'217',
#  u'2174',
#  u'2180',
#  u'21st',
#  u'22',
#  u'2201',
#  u'221',
#  u'2229',
#  u'223',
#  u'224',
#  u'2245',
#  u'2248',
#  u'225',
#  u'2263951',
#  u'22728',
#  u'22d',
#  u'23',
#  u'230',
#  u'2330',
#  u'2363',
#  u'2372',
#  u'2397997',
#  u'23rd',
#  u'24',
#  u'2401',
#  u'241',
#  u'2419',
#  u'243',
#  u'24th',
#  u'25',
#  u'250',
#  u'251',
#  u'252',
#  u'2566',
#  u'25am',
#  u'25th',
#  u'26',
#  u'26112233',
#  u'2612',
#  u'2632026830',
#  u'2645',
#  u'2649',
#  u'27',
#  u'270',
#  u'276',
#  u'278',
#  u'28',
#  u'282001',
#  u'2848',
#  u'287',
#  u'2873',
#  u'28th',
#  u'29',
#  u'2912',
#  u'2972',
#  u'29th',
#  u'2am',
#  u'2bb',
#  u'2nd',
#  u'2pm',
#  u'2r',
#  u'30',
#  u'300',
#  u'301',
#  u'3014',
#  u'303',
#  u'30308',
#  u'30am',
#  u'30arn',
#  u'30pm',
#  u'30th',
#  u'31',
#  u'310',
#  u'312',
#  u'313',
#  u'315',
#  u'3186',
#  u'31st',
#  u'32',
#  u'320',
#  u'3261',
#  u'32nd',
#  u'33',
#  u'330',
#  u'3321',
#  u'34',
#  u'345',
#  u'3481',
#  u'35',
#  u'36',
#  u'3611',
#  u'37',
#  u'371',
#  u'38',
#  u'3820',
#  u'38203',
#  u'38929',
#  u'39',
#  u'390',
#  u'3anuary',
#  u'3dy5rzw50bg',
#  u'3i',
#  u'3k',
#  u'3n',
#  u'3pm',
#  u'3prn',
#  u'3rd',
#  u'40',
#  u'400',
#  u'401',
#  u'4020',
#  u'404',
#  u'41',
#  u'4120',
#  u'4178',
#  u'42',
#  u'4204',
#  u'422',
#  u'4289',
#  u'429',
#  u'43',
#  u'439',
#  u'44',
#  u'440',
#  u'4443',
#  u'445',
#  u'4451',
#  u'447',
#  u'45',
#  u'4520',
#  u'456',
#  u'45am',
#  u'45pm',
#  u'46',
#  u'4600',
#  u'4636',
#  u'4691',
#  u'47',
#  u'475',
#  u'476',
#  u'47697002',
#  u'48',
#  u'485',
#  u'486',
#  u'49',
#  u'4969',
#  u'49968',
#  u'4am',
#  u'4awiya',
#  u'4bedinh',
#  u'4pm',
#  u'50',
#  u'500',
#  u'5029',
#  u'505',
#  u'509',
#  u'50am',
#  u'50k',
#  u'50th',
#  u'51',
#  u'510',
#  u'512',
#  u'515',
#  u'5173',
#  u'52',
#  u'5240',
#  u'5256',
#  u'527',
#  u'5290',
#  u'53',
#  u'5300',
#  u'5302',
#  u'53pm',
#  u'54',
#  u'540',
#  u'540pm',
#  u'5470',
#  u'55',
#  u'550',
#  u'5508',
#  u'55pam',
#  u'56',
#  u'5600',
#  u'562',
#  u'565',
#  u'57',
#  u'571',
#  u'5723',
#  u'58',
#  u'5855',
#  u'58754',
#  u'59',
#  u'593',
#  u'5932',
#  u'594',
#  u'595',
#  u'596',
#  u'597',
#  u'598',
#  u'599',
#  u'5cb0045096',
#  u'5cb0045248',
#  u'5cb0045459',
#  u'5cb0045650',
#  u'5cb0045653',
#  u'5cb0045671',
#  u'5cb0045672',
#  u'5cb0045673',
#  u'5cb0045674',
#  u'5cb0045675',
#  u'5cb0045676',
#  u'5cb0045677',
#  u'5cb0045678',
#  u'5cb0045679',
#  u'5cb0045680',
#  u'5cb0045681',
#  u'5cb0045682',
#  u'5cb0045683',
#  u'5cb0045684',
#  u'5cb0045685',
#  u'5cb0045799',
#  u'5fm',
#  u'5k',
#  u'5on',
#  u'5pm',
#  u'5th',
#  u'60',
#  u'600',
#  u'601',
#  u'602',
#  u'603',
#  u'604',
#  u'60604',
#  u'60606',
#  u'60610',
#  u'60661',
#  u'61',
#  u'6101',
#  u'613',
#  u'614',
#  u'62',
#  u'6200',
#  u'6240',
#  u'6250',
#  u'63',
#  u'630pm',
#  u'6315',
#  u'6317',
#  u'6323',
#  u'64',
#  u'6421',
#  u'643',
#  u'647',
#  u'65',
#  u'650',
#  u'6607',
#  u'663',
#  u'6676',
#  u'67',
#  u'6727',
#  u'674_225506_9',
#  u'6760',
#  u'68',
#  u'6805',
#  u'687',
#  u'69',
#  u'6am',
#  u'6pm',
#  u'6pr',
#  u'6th',
#  u'70',
#  u'700',
#  u'70064',
#  u'7008',
#  u'702',
#  u'7096',
#  u'7098',
#  u'71',
#  u'711',
#  u'7128',
#  u'717',
#  u'71r',
#  u'7203',
#  u'7209',
#  u'722',
#  u'72204',
#  u'72205',
#  u'7261',
#  u'727',
#  u'7283',
#  u'7288',
#  u'73',
#  u'730',
#  u'7311',
#  u'732',
#  u'736',
#  u'74',
#  u'741',
#  u'7495',
#  u'75',
#  u'7516',
#  u'752',
#  u'7551',
#  u'7555',
#  u'7647',
#  u'77',
#  u'7719',
#  u'7782',
#  u'7869',
#  u'797',
#  u'7994',
#  u'7am',
#  u'7n',
#  u'7pin',
#  u'7pm',
#  u'7prn',
#  u'7th',
#  u'80',
#  u'800',
#  u'8000',
#  u'8100',
#  u'8132',
#  u'813674587',
#  u'815',
#  u'81654',
#  u'819',
#  u'820',
#  u'822',
#  u'830',
#  u'8300',
#  u'84',
#  u'848',
#  u'850',
#  u'8633',
#  u'866',
#  u'8690',
#  u'89',
#  u'8906',
#  u'89092071',
#  u'89092072',
#  u'89092073',
#  u'89092074',
#  u'89092075',
#  u'89092076',
#  u'89092077',
#  u'89092078',
#  u'89092079',
#  u'89092080',
#  u'89092081',
#  u'89092082',
#  u'89092083',
#  u'8am',
#  u'8pm',
#  u'8th',
#  u'8v',
#  u'90',
#  u'900',
#  u'90404',
#  u'906',
#  u'9071',
#  u'90s',
#  u'91',
#  u'9105',
#  u'9111',
#  u'91301',
#  u'914',
#  u'916',
#  u'92',
#  u'928',
#  u'9294',
#  u'93',
#  u'930',
#  u'930am',
#  u'944',
#  u'9533',
#  u'9598',
#  u'9602',
#  u'967',
#  u'98',
#  u'981',
#  u'9842',
#  u'989',
#  u'9995',
#  u'9am',
#  u'9arn',
#  u'9arri',
#  u'9k',
#  u'9pm',
#  u'9th',
#  u'9w',
#  u'_i',
#  u'_juan',
#  u'aa',
#  u'aaj',
#  u'aam',
#  u'aaron',
#  u'aasia',
#  u'ababa',
#  u'abandon',
#  u'abandoned',
#  u'abandonment',
#  u'abbas',
#  u'abbasi',
#  u'abbaszadeh',
#  u'abd',
#  u'abduction',
#  u'abdulkadir',
#  u'abdulla',
#  u'abdullah',
#  u'abe',
#  u'abeclinh',
#  u'abed',
#  u'abedin',
#  u'abedine',
#  u'abedinh',
#  u'abedir',
#  u'abedln',
#  u'abid',
#  u'abide',
#  u'abilities',
#  u'ability',
#  u'abl',
#  u'able',
#  u'aboard',
#  u'abolished',
#  u'abolition',
#  u'abomination',
#  u'abortion',
#  u'abortions',
#  u'aboul',
#  u'about',
#  u'above',
#  u'abraham',
#  u'abramson',
#  u'abroad',
#  u'absence',
#  u'absent',
#  u'absolute',
#  u'absolutely',
#  u'absorb',
#  u'abstentions',
#  u'abstract',
#  u'abstruse',
#  u'abt',
#  u'abu',
#  u'abuse',
#  u'abuses',
#  u'abusing',
#  u'abyei',
#  u'academic',
#  u'academics',
#  u'academy',
#  u'accede',
#  u'acceded',
#  u'accelerated',
#  u'accent',
#  u'accentuates',
#  u'accept',
#  u'acceptable',
#  u'accepted',
#  u'accepting',
#  u'accepts',
#  u'access',
#  u'accessibility',
#  u'accessible',
#  u'accident',
#  u'accion',
#  u'acclaimed',
#  u'accommodating',
#  u'accompanies',
#  u'accompany',
#  u'accompanying',
#  u'accomplish',
#  u'accomplished',
#  u'accomplishment',
#  u'accomplishments',
#  u'accord',
#  u'accordance',
#  u'according',
#  u'accordingly',
#  u'account',
#  u'accountability',
#  u'accountable',
#  u'accounting',
#  u'accounts',
#  u'accredited',
#  u'acct',
#  u'acctld',
#  u'accurate',
#  u'accusations',
#  u'accuse',
#  u'accused',
#  u'accuses',
#  u'accusing',
#  u'acheson',
#  u'achieve',
#  u'achieved',
#  u'achievement',
#  u'achievements',
#  u'achieving',
#  u'ackerman',
#  u'acknowledge',
#  u'acknowledged',
#  u'acknowledgement',
#  u'acknowledgements',
#  u'acknowledges',
#  u'acknowledging',
#  u'aclb',
#  u'aclintonemail',
#  u'acquire',
#  u'acquiring',
#  u'acreage',
#  u'acropolis',
#  u'across',
#  u'act',
#  u'acted',
#  u'acting',
#  u'action',
#  u'action_memo_to_s_on_yeosu_2012_participation_5',
#  u'actionable',
#  u'actionaid',
#  u'actions',
#  u'active',
#  u'actively',
#  u'activist',
#  u'activists',
#  u'activities',
#  u'activity',
#  u'actor',
#  u'actors',
#  u'acts',
#  u'actual',
#  u'actually',
#  u'acute',
#  u'acv',
#  u'ad',
#  u'adam',
#  u'adamant',
#  u'adams',
#  u'adamsds',
#  u'adaptations',
#  u'add',
#  u'added',
#  u'adding',
#  u'addis',
#  u'addition',
#  u'additional',
#  u'additionally',
#  u'additions',
#  u'address',
#  u'addressed',
#  u'addressee',
#  u'addresses',
#  u'addressing',
#  u'adds',
#  u'adele',
#  u'aden',
#  u'adequate',
#  u'adequately',
#  u'ades',
#  u'adjointe',
#  u'adjust',
#  u'adjustments',
#  u'adl',
#  u'adler',
#  u'adlerce',
#  u'admin',
#  u'administered',
#  u'administration',
#  u'administrativa',
#  u'administrative',
#  u'administrator',
#  u'admirable',
#  u'admiral',
#  u'admiration',
#  u'admire',
#  u'admired',
#  u'admires',
#  u'admit',
#  u'admits',
#  u'admitted',
#  u'admitting',
#  u'admonitions',
#  u'adolescent',
#  u'adopt',
#  u'adopted',
#  u'adopting',
#  u'adoption',
#  u'adoptions',
#  u'adores',
#  u'adoring',
#  u'adult',
#  u'adulthood',
#  u'adults',
#  u'advance',
#  u'advanced',
#  u'advancing',
#  u'advantage',
#  u'adventure',
#  u'adventuring',
#  u'adventurous',
#  u'advertised',
#  u'advertising',
#  u'advice',
#  u'advise',
#  u'advised',
#  u'adviser',
#  u'advises',
#  u'advising',
#  u'advisor',
#  u'advisors',
#  u'advisory',
#  u'advocacy',
#  u'advocate',
#  u'advocates',
#  u'advocating',
#  u'aeirig',
#  u'af',
#  u'af1',
#  u'afar',
#  u'afb',
#  u'affable',
#  u'affair',
#  u'affaires',
#  u'affairs',
#  u'affect',
#  u'affected',
#  u'affecting',
#  u'affection',
#  u'affectionately',
#  u'affiliate',
#  u'affiliated',
#  u'affinity',
#  u'affirm',
#  u'affirmed',
#  u'affirms',
#  u'afford',
#  u'affordable',
#  u'affordably',
#  u'afghan',
#  u'afghanistan',
#  u'afghans',
#  u'afonso',
#  u'africa',
#  u'african',
#  u'africans',
#  u'africom',
#  u'afridi',
#  u'afro',
#  u'aft',
#  u'after',
#  u'aftermath',
#  u'afternoon',
#  u'aftershocks',
#  u'afterward',
#  u'aga',
#  u'again',
#  u'against',
#  u'age',
#  u'agence',
#  u'agencies',
#  u'agency',
#  u'agenda',
#  u'agendas',
#  u'ages',
#  u'aggravating',
#  u'aggression',
#  u'aggressive',
#  u'aghanistan',
#  u'ago',
#  u'agoa',
#  u'agra',
#  u'agree',
#  u'agreed',
#  u'agreeing',
#  u'agreement',
#  u'agreements',
#  u'agrees',
#  u'agricultural',
#  u'agriculture',
#  u'agroforester',
#  u'agu',
#  u'ahead',
#  u'ahern',
#  u'ahh',
#  u'ahmadinejad',
#  u'ahmed',
#  u'ahmet',
#  u'ahrocdovl2fsdw1uas5rzw50bgf3lmvkdo',
#  u'ahrocdovl3d3dy5rzw50bgf3lmvkds9kzxbocy9hb',
#  u'ahrocdovl3d3dy5rzw50bgf3lmvkds9kzxbocy9jbg',
#  u'ai',
#  u'aid',
#  u'aide',
#  u'aides',
#  u'aids',
#  u'aig',
#  u'ail',
#  u'aim',
#  u'aimed',
#  u'aiming',
#  u'aini',
#  u'aio',
#  u'aipac',
#  u'air',
#  u'airbase',
#  u'aircraft',
#  u'aired',
#  u'airlift',
#  u'airline',
#  u'airlines',
#  u'airport',
#  u'airports',
#  ...]

# %%
# Generate train_dtm
train_dtm = vect.transform(X_train)
# Generate test_dtm
test_dtm = vect.transform(X_test)

# %%
# Import MultinomialNB
from sklearn.naive_bayes import MultinomialNB
# Create model
nb = MultinomialNB()
# Fit model
nb.fit(train_dtm, y_train)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
#now let's move on to LSI analysis

# %%
#time to train/test/split otherwise we will have an overfitting problem
# Import train_test_split
from sklearn.cross_validation import train_test_split
# Split the data into a 70/30 train/test split
df_emails_train, df_emails_test = train_test_split(df_emails.RawText, test_size=0.3)

# %%
## FOR REUTERS
# We're not concerned with the category for now, so select out only the text column into a Series object 'docs'
docs = df_emails_train
docs.head()
# Out:
# 7630    UNCLASSIFIED U.S. Department of State Case No....
# 572     B6\nUNCLASSIFIED U.S. Department of State Case...
# 5430    UNCLASSIFIED U.S. Department of State Case No....
# 1260    UNCLASSIFIED U.S. Department of State Case No....
# 7753    UNCLASSIFIED U.S. Department of State Case No....
# Name: RawText, dtype: object

# %%
# Let's load the nltk English stopwords list to ignore those in our analysis
import nltk
from nltk.corpus import stopwords
## Download various nltk corpora (used for stopwords here)
#nltk.download()
## Print all english stopwords
stopwords = stopwords.words('english')

# %%
'''
The way we're going to attack this is to build out the TDM matrix with the documents as rows and terms as columns
and then we'll call the transpose operator to flip it to the representation we need for LSI.

We need the following:
    1.  Dictionary of word --> index to define vectors (index for each term)
    2.  Dictionary of word --> total count to get the global (IDF)
    3.  Dictionary of word --> document count for each document to get the local (TF) weighting
'''

# Implement a function that returns the 3 dictionaries that we need above
def find_frequencies(docs):
    term_indices = {} ## This is #1 above
    currentIndex = 0 ## This is the counter to make sure we correctly populate the term indices in order
    corpus_bag = {} ## This is #2 above
    doc_bags = [] ## This is the collection for #3 above
    for i, doc in docs.iteritems():
        doc_bag = {} ## This is the dictionary of term frequencies for the doc we're currently examining, doc_bags stores a collection of these
        ## TODO: Tokenize each document with nltk
        doc_tokens = nltk.word_tokenize(doc)
        ## TODO: For each token in the current document:
        for word in doc_tokens:
            ## Optionally ignore stopword and continue
            ## Throw out stopwords
            ##if word in stopwords:
                ##    continue
            ## If the word is new (not in term_indices): 
            if word not in term_indices:
                ## add it to term_indices and give it the index value currentIndex, increment currentIndex
                term_indices[word] = currentIndex
                currentIndex += 1
                ## add it to the corpus_bag with count 1
                corpus_bag[word] = 1
                ## add it to the current doc_bag with count 1
                doc_bag[word] = 1
            ## If the word is not new:
            else:
                ## increment the corpus_bag
                corpus_bag[word] = corpus_bag[word] + 1
                ## If the word is already in the doc_bag, increment that counter, else set it to 1
                if word in doc_bag:
                    doc_bag[word] = doc_bag[word] + 1
                else:
                    doc_bag[word] = 1
        doc_bags.append(doc_bag)
    return term_indices, corpus_bag, doc_bags

# %%
term_indices, corpus_bag, doc_bags = find_frequencies(docs)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-96-6adf44f0f59f> in <module>()
# ----> 1 term_indices, corpus_bag, doc_bags = find_frequencies(docs)
#
# <ipython-input-95-1c779a4bb1d4> in find_frequencies(docs)
#      18         doc_bag = {} ## This is the dictionary of term frequencies for the doc we're currently examining, doc_bags stores a collection of these
#      19         ## TODO: Tokenize each document with nltk
# ---> 20         doc_tokens = nltk.word_tokenize(doc)
#      21         ## TODO: For each token in the current document:
#      22         for word in doc_tokens:
#
# /Users/norahajjar/anaconda/lib/python2.7/site-packages/nltk/tokenize/__init__.pyc in word_tokenize(text, language)
#     102     :param language: the model name in the Punkt corpus
#     103     """
# --> 104     return [token for sent in sent_tokenize(text, language)
#     105             for token in _treebank_word_tokenize(sent)]
#     106
#
# /Users/norahajjar/anaconda/lib/python2.7/site-packages/nltk/tokenize/__init__.pyc in sent_tokenize(text, language)
#      87     """
#      88     tokenizer = load('tokenizers/punkt/{0}.pickle'.format(language))
# ---> 89     return tokenizer.tokenize(text)
#      90
#      91 # Standard word tokenizer.
#
# /Users/norahajjar/anaconda/lib/python2.7/site-packages/nltk/tokenize/punkt.pyc in tokenize(self, text, realign_boundaries)
#    1224         Given a text, returns a list of the sentences in that text.
#    1225         """
# -> 1226         return list(self.sentences_from_text(text, realign_boundaries))
#    1227
#    1228     def debug_decisions(self, text):
#
# /Users/norahajjar/anaconda/lib/python2.7/site-packages/nltk/tokenize/punkt.pyc in sentences_from_text(self, text, realign_boundaries)
#    1272         follows the period.
#    1273         """
# -> 1274         return [text[s:e] for s, e in self.span_tokenize(text, realign_boundaries)]
#    1275
#    1276     def _slices_from_text(self, text):
#
# /Users/norahajjar/anaconda/lib/python2.7/site-packages/nltk/tokenize/punkt.pyc in span_tokenize(self, text, realign_boundaries)
#    1263         if realign_boundaries:
#    1264             slices = self._realign_boundaries(text, slices)
# -> 1265         return [(sl.start, sl.stop) for sl in slices]
#    1266
#    1267     def sentences_from_text(self, text, realign_boundaries=True):
#
# /Users/norahajjar/anaconda/lib/python2.7/site-packages/nltk/tokenize/punkt.pyc in _realign_boundaries(self, text, slices)
#    1302         """
#    1303         realign = 0
# -> 1304         for sl1, sl2 in _pair_iter(slices):
#    1305             sl1 = slice(sl1.start + realign, sl1.stop)
#    1306             if not sl2:
#
# /Users/norahajjar/anaconda/lib/python2.7/site-packages/nltk/tokenize/punkt.pyc in _pair_iter(it)
#     309     it = iter(it)
#     310     prev = next(it)
# --> 311     for el in it:
#     312         yield (prev, el)
#     313         prev = el
#
# /Users/norahajjar/anaconda/lib/python2.7/site-packages/nltk/tokenize/punkt.pyc in _slices_from_text(self, text)
#    1278         for match in self._lang_vars.period_context_re().finditer(text):
#    1279             context = match.group() + match.group('after_tok')
# -> 1280             if self.text_contains_sentbreak(context):
#    1281                 yield slice(last_break, match.end())
#    1282                 if match.group('next_tok'):
#
# /Users/norahajjar/anaconda/lib/python2.7/site-packages/nltk/tokenize/punkt.pyc in text_contains_sentbreak(self, text)
#    1323         """
#    1324         found = False # used to ignore last token
# -> 1325         for t in self._annotate_tokens(self._tokenize_words(text)):
#    1326             if found:
#    1327                 return True
#
# /Users/norahajjar/anaconda/lib/python2.7/site-packages/nltk/tokenize/punkt.pyc in _annotate_second_pass(self, tokens)
#    1458         heuristic (4.1.2) and frequent sentence starter heuristic (4.1.3).
#    1459         """
# -> 1460         for t1, t2 in _pair_iter(tokens):
#    1461             self._second_pass_annotation(t1, t2)
#    1462             yield t1
#
# /Users/norahajjar/anaconda/lib/python2.7/site-packages/nltk/tokenize/punkt.pyc in _pair_iter(it)
#     308     """
#     309     it = iter(it)
# --> 310     prev = next(it)
#     311     for el in it:
#     312         yield (prev, el)
#
# /Users/norahajjar/anaconda/lib/python2.7/site-packages/nltk/tokenize/punkt.pyc in _annotate_first_pass(self, tokens)
#     575           - ellipsis_toks: The indices of all ellipsis marks.
#     576         """
# --> 577         for aug_tok in tokens:
#     578             self._first_pass_annotation(aug_tok)
#     579             yield aug_tok
#
# /Users/norahajjar/anaconda/lib/python2.7/site-packages/nltk/tokenize/punkt.pyc in _tokenize_words(self, plaintext)
#     540         """
#     541         parastart = False
# --> 542         for line in plaintext.split('\n'):
#     543             if line.strip():
#     544                 line_toks = iter(self._lang_vars.word_tokenize(line))
#
# UnicodeDecodeError: 'ascii' codec can't decode byte 0xe2 in position 10: ordinal not in range(128)

# %%
print len(term_indices)
# Out:
#   File "<ipython-input-98-4fcd0a884712>", line 1
#     print len(term_indices)
#             ^
# SyntaxError: invalid syntax

# %%
print len(doc_bags[0])
print doc_bags[0]
# Out:
#   File "<ipython-input-99-e551b2b5c1d7>", line 1
#     print len(doc_bags[0])
#             ^
# SyntaxError: invalid syntax

# %%
#lets take the column raw data and do some analysis on it 

df_emails.RawText.info()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-103-c394f672bcb6> in <module>()
#       1 #lets take the column raw data and do some analysis on it
#       2
# ----> 3 df_emails.RawText.info()
#
# /Users/norahajjar/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    2358                 return self[name]
#    2359             raise AttributeError("'%s' object has no attribute '%s'" %
# -> 2360                                  (type(self).__name__, name))
#    2361
#    2362     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'info'

# %%
df_emails.RawText.value_counts()
# Out:
# UNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05758700 Date: 06/30/2015\nRELEASE IN PART\nB6\nFrom: H <hrod17@clintonemail.com>\nSent: Friday, June 5, 2009 6:08 PM\nTo: 'ValmoroLJ@state.gov.\nSubject: Fw: Invitation to Copenhagen Key to Climate Investing conference\nLet's discuss at our next mtg.\nOriginal Message\nFrom: Mills, Cheryl D <MillsCD@state.gov>\nTo: H\nSent: Thu Jun 04 14:07:55 2009\nSubject: FW: Invitation to Copenhagen Key to Climate Investing conference\nFYI\nOriginal Message\nFrom: Dick Gephardt [mailto\nSent: Thursday, June 04, 2009 7:47 AM\nTo: Mills, Cheryl D\nSubject: Re: Invitation to Copenhagen Key to Climate Investing conference\nCheryl - Thank you so much for considering this invitation. I am sure the sponsors would be absolutely thrilled to have\nSecretary Clinton appear.\nIn passing let me say what an extraordinary job you are all doing. As an American citizen it gives me great confidence\nand pride to see Secretary Clinton representing our country with such skill and grace. All Best, Dick\nOriginal Message\nFrom: Mills, Cheryl D <MillsCD@state.gov>\nTo: O'Sullivan, Nigel\nCc: Dick Gephardt; Valmoro, Lona J<ValmoroLJ@state.gov>\nSent: Wed Jun 03 13:55:34 2009\nSubject: RE: Invitation to Copenhagen Key to Climate Investing conference\nThank you so much.\nI am adding Lona — and we will make sure she reviews to address.\nBest.\ncdm\nUNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05758700 Date: 06/30/2015\nUNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05758700 Date: 06/30/2015\nFrom: Bradley, Fiona [mailto On Behalf Of O'Sullivan, Nigel B6\nSent: Wednesday, June 03, 2009 11:32 AM\nTo: Mills, Cheryl D\nCc: dickgephardt B6\nSubject: Invitation to Copenhagen Key to Climate Investing conference\nDear Cheryl\nFollowing a few discussions with Dick Gephardt - I have pleasure in laying out fairly detailed information about a\nconference that is being held in Demark on 3-4 December 2009.\nWe have made the note reasonably in-depth so hopefully will provide you with sufficient background. The organisers of\nthe event which are ATP - the largest Danish Pension Fund and the Climate Consortium Denmark are being sponsored\nand backed by the Danish government and they were very hopeful that Hillary would be able to be the key note speaker\nat the conference for reasons that they have identified in the attached briefing document.\nWe were hoping to establish whether this event would be of interest for Hillary to appear and if she was available we\nwould then arrange for the formal invite to be sent out by the Danish Government.\nIf we can provide any further clarification, please do not hesitate to contact us.\nWith very Best wishes\nNigel\nNigel O'Sullivan\nGoldman Sachs International\nPeterborough Court I 133 Fleet Street\nLondon EC4A 2BB\nB6\nAuthorised and regulated by the Financial Services Authority © Copyright 2007 The Goldman Sachs Group, Inc. All rights\nreserved.\nThis message may contain information that is confidential or privileged. If you are not the intended recipient, please\nadvise the sender immediately and delete this message.\nUNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05758700 Date: 06/30/2015\nUNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05758700 Date: 06/30/2015\nSee http://www.gs.com/disclaimer/email for further information on confidentiality and the risks inherent in electronic\ncommunication. See http://www.gs.com/disclaimer/email-salesandtrading.html for important risk disclosure, conflicts\nof interest and other terms and conditions relating to the e-mail and your reliance on information contained in it.\nGoldman Sachs International ("GSI") is authorised and regulated by The Financial Services Authority and appears in the\nFSA register under number 142888. GS! is subject to the FSA rules and guidance, details of which can be found on the\nFSA's website at http://www.fsa.gov.uk < ...
# UNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05769154 Date: 08/31/2015\nRELEASE IN PART B6\nFrom: PIR <preines\nSent: Tuesday, March 30, 2010 7:02 PM\nTo: H\nCc: Jake Sullivan\nSubject: Re: Canada\nJust the stuff from yesterday. Maybe one of the cable nets or talking heads made a to do about it.\nBut I'm surprised because it didn't seem anyone here cared, was all Canada\nOriginal Message\nFrom: Evergreen\nTo: Jake Sullivan\nTo: PIR\nSubject: Canada\nSent: Mar 30, 2010 6:59 PM\nA friend just emailed me telling me she was so sorry I had such a tough day in Canada. What's the news that suggests\nthat back here?\nUNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05769154 Date: 08/31/2015\n                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# UNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05759126 Date: 06/30/2015\nRELEASE IN PART\nB5\nFrom: H <hrod17@clintonemail.com>\nSent: Wednesday, August 5, 2009 2:54 PM\nTo: 'millscd@state.gov'\nSubject: Re: Higher Education Dinner on August 17 - Guest\nI can't pull up the whole email but assume it is fine to go. Any other news? We can talk later if needed.\nOriginal Message\nFrom: Mills, Cheryl D <MillsCD@state.gov>\nTo: H\nSent: Wed Aug 05 11:39:17 2009\nSubject: FW: Higher Education Dinner on August 17 - Guest\nHRC:\nAdded\nIn speaking to John he pointed out that frame is also to have some of the larger institutions to do and create\ndevelopment in Africa and other countries and they must see themselves as having obligation of being part of solution.\nSee list.\nOriginal Message\nFrom: Mills, Cheryl D\nSent: Wednesday, August 05, 2009 11:24 AM\nTo: Sullivan, Jacob J; Abedin, Huma; Valmoro, Lona J\nCc: Fedoroff, Nina V (STAS); Slaughter, Anne-Marie; Chollet, Derek H; Klevorick, Caitlin B; Smith, Jeannemarie E\nSubject: Higher Education Dinner on August 17 - Guest\nJake/Huma/Lona:\nI've got to have Lona get invites out today - the list is 18 after speaking with the Secretary on theory we will have yield of\n12 - 14.\nBefore I have Lona invite anyone, I want to phase invites so our highest priorities have chance to response first and need\nto know how big is too big to work; I have targeted 12-14 outside guests - given an expectation of 6-8 government folks.\nProposed Outside Dinner Guest List:\nUNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05759126 Date: 06/30/2015\nUNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05759126 Date: 06/30/2015\nUNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05759126 Date: 06/30/2015\nUNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05759126 Date: 06/30/2015\nPotential other invite:\nUNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05759126 Date: 06/30/2015\n                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# UNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05764048 Date: 07/31/2015\nRELEASE IN PART\nB6\nFrom: Abedin, Huma <AbedinH@state.gov>\nSent: Tuesday, September 15, 2009 4:17 PM\nTo: Rosemarie Howe; H\nSubject: RE: Arranging\nB6\nOriginal Message\nFrom: Rosemarie Howe\nSent: Tuesday, September 15, 2009 3:04 PM\nTo: H\nCc: Abedin, Huma\nSubject: Re: Arranging\nSent from my iPhone\nOn Sep 15, 2009, at 2:39 PM, H <HDR22@clintonemail.com> wrote:\n> Yes. Thx.\n> Original Message\n> From: Rosemarie Howe\n> To: H\n> Cc: Huma Abedin <abedinh@state.gov>\n> Sent: Tue Sep 15 12:43:47 2009\n> Subject: Arranging\n> Sent from my iPhone\nUNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05764048 Date: 07/31/2015\n                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     ...
# UNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05766157 Date: 08/31/2015\nRELEASE IN PART B6\nFrom: Jiloty, Lauren C <JilotyLC@state.gov>\nSent: Sunday, December 13, 2009 4:30 PM\nTo: H; Abedin, Huma\nSubject Re: Call list\nOk. Yes ray lahood is still on.\nOriginal Message --\nFrom: H <HDR22@clintonemail.com>\nTo: Jiloty, Lauren C\nCc: Huma Abedin\nSent: Sun Dec 13 16:27:18 2009\nSubject: Call list\nPls add former Amb Frank Wisner. And is Ray La Hood still on it--pls be sure he is. Thx.\nUNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05766157 Date: 08/31/2015\n                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ...
# UNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05763238 Date: 06/30/2015\nRELEASE IN PART\nB5,B6\nFrom: H <hrod17@clintonemail.com>\nSent: Tuesday, December 29, 2009 10:59 PM\nTo: 'millscd@state.gov'\nSubject: Re: 12/21 Revisions to Internet Freedom Speech\nIs there something magic about that date?\nOriginal Message\nFrom: Mills, Cheryl D <MillsCD@state.gov>\nTo: H\nSent: Tue Dec 29 22:58:09 2009\nSubject: RE: 12/21 Revisions to Internet Freedom Speech\nGood - you good for us to sign off on giving a speech on 21 jan at newseum?\nOriginal Message\nFrom: H [mailto:HDR22@clintonemail.com]\nSent: Tuesday, December 29, 2009 10:56 PM\nTo: Mills, Cheryl D\nSubject: Re: 12/21 Revisions to Internet Freedom Speech\nThis looks fine and makes me sound like a techie (which is good, albeit a stretch).\nOriginal Message\nFrom: Mills, Cheryl D <MillsCD@state.gov>\nTo: H\nCc: Abedin, Huma <AbedinH@state.gov>\nSent: Tue Dec 29 22:28:38 2009\nSubject: FW: 12/21 Revisions to Internet Freedom Speech\nHRC:\nThis is an early preview of the speech (which is still in progress).\nLet me know what you think conceptually after you read.\nCdm\nSPEECH COVER PAGE\nUNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05763238 Date: 06/30/2015\nUNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05763238 Date: 06/30/2015\nINFORMATION FREEDOM SPEECH\nLead Writer: Tomicah Tillemann\nPhone: 7-9842/\nEmail: tillemannts@state.gov\nVETTERS: PLEASE INITIAL HERE\nSECRETARY OF STATE HILLARY RODHAM CLINTON ADDRESS ON INTERNET FREEDOM THE NEWSEUM, WASHINGTON, DC\nJANUARY 6, 2009\nUNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05763238 Date: 06/30/2015\nUNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05763238 Date: 06/30/2015\nUNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05763238 Date: 06/30/2015\nUNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05763238 Date: 06/30/2015\nUNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05763238 Date: 06/30/2015\nUNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05763238 Date: 06/30/2015\nUNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05763238 Date: 06/30/2015\nUNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05763238 Date: 06/30/2015\nUNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05763238 Date: 06/30/2015\nUNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05763238 Date: 06/30/2015\nUNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05763238 Date: 06/30/2015\nUNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05763238 Date: 06/30/2015\nFrom: Tillemann, Tomicah S\nSent: Monday, December 21, 2009 2:33 PM\nTo: Mills, Cheryl D; Toiv, Nora F; Sullivan, Jacob J; Ross, Alec 1; Slaughter, Anne-Marie; Chollet, Derek H; Crowley, Philip\nCc: Muscatine, Lissa; S_SpecialAssistants\nSubject: Fw: 12/21 Revisions to Internet Freedom Speech\nUNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05763238 Date: 06/30/2015\nUNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05763238 Date: 06/30/2015\nFolks,\nI've attached the latest draft of the Internet freedom speech. It should be ready for the Secretary. This version addresses\nissues raised in the last draft with three exceptions:\nPlease let me know if any of you have further questions or comments.\nThanks,\nTomicah\nFrom: Tomicah Tillemann\nTo: Tillemann, Tomicah S\nSent: Mon Dec 21 14:17:45 2009\nSubject: 12/21 Revisions to Internet Freedom Speech\nUNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05763238 Date: 06/30/2015\n                                                                                                                                                                                                                                           ...
# UNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05764618 Date: 07/31/2015\nRELEASE IN PART\nB6\nFrom: Abedin, Huma <AbedinH@state.gov>\nSent: Saturday, September 19, 2009 10:16 AM\nTo: Oscar Flores\nCc: H\nSubject: Fw: Brookings As Prepared\nAttachments: UNGA As Prepared.doc; ATT155913.txt\nOscar pls print for hrc. She's expecting it.\nOriginal Message ----\nFrom: Muscatine Lissa B6\nTo: Abedin, Huma; Sullivan, Jacob J\nSent: Fri Sep 18 10:01:31 2009\nSubject: Brookings As Prepared\nYou guys might want to read through one more time in case I missed any typos or anything else. I was integrating all this\nstuff very fast. Thx.\nUNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05764618 Date: 07/31/2015\n                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# UNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05761431 Date: 06/30/2015\nRELEASE IN PART B6\nFrom: H <hrod17@clintonemail.com>\nSent: Sunday, December 13, 2009 2:20 PM\nTo: 'muscatinel@state.gov'; 'daniel.baer\nCc: 'ValmoroU@state.gov'; Huma Abedin\nSubject: Re: Speech\nCould we do at 4:30 or 6:45?\nOriginal Message\nFrom: Muscatine, Lissa <MuscatineL@state.gov>\nTo: H; daniel.baer\nCc: Valmoro, Lona J <ValmoroU@state.gov>; Huma Abedin\nSent: Sun Dec 13 14:16:18 2009\nSubject: Re: Speech\nI agree with Dan about the ornament problem. The draft needs refinement not re-working. And a call is a great idea. I\nam just getting off a plane but could be available any time after 4 pm or so if that works for you.\nOriginal Message\nFrom: H <HDR22@clintonemail.com>\nTo: Muscatine, Lissa; 'claniel.baer\nCc: Valmoro, Lona J; Huma Abedin\nSent: Sun Dec 13 07:56:59 2009\nSubject: Speech\nThe latest draft is getting closer. And I agree w Dan that we have to be careful not to topple the tree w too many\nornaments. That said, I'd like to have a call w you (and anyone else who you think should be on) this afternoon or\nevening to raise a few points. I'm copying Lona and Huma so they can help schedule it. Thanks for all your good work.\nUNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05761431 Date: 06/30/2015\n                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     ...
# UNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05759828 Date: 06/30/2015\nRELEASE IN PART\nB6\nFrom: H <hrod17@clintonemail.com>\nSent: Monday, September 28, 2009 10:56 AM\nTo: emillscd@state.gov'\nCc: Huma Abed in\nSubject: Re: Friday Presentation on Urgent Threat - Bill Burns will not be at the Retreat\nCheryl--we should postpone until we get Bill there.\nOriginal Message\nFrom: Mills, Cheryl D <MillsCD@state.gov>\nTo: H\nCc: Sullivan, Jacob J<Sullivann@state.gov>; Abedin, Huma <AbedinH@state.gov>\nSent: Mon Sep 28 10:26:39 2009\nSubject: FW: Friday Presentation on Urgent Threat - Bill Burns will not be at the Retreat\nFYI below\nFrom: Burns, William J\nSent: Monday, September 28, 2009 10:21 AM\nTo: Mills, Cheryl D\nSubject: RE: Friday Presentation on Urgent Threat\nCheryl,\nI'll be in Geneva with P5+1 and Iranians Oct 1-2. Won't get back at earliest until late evening Oct 2 — more likely Oct 3.\nBill\nFrom: Mills, Cheryl D\nSent: Monday, September 28, 2009 10:19 AM\nTo: Burns, William 1; Holbrooke, Richard C; Mitchell, George J; Boswell, Eric J\nCc: Toiv, Nora F; Woytovech, Suzonne M; Rudman, Mara; Dejban, Donna D;\nSubject: Friday Presentation on Urgent Threat\nDear Gentlemen:\nUNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05759828 Date: 06/30/2015\nUNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05759828 Date: 06/30/2015\nOn Friday, Oct 2, 2009, the Secretary is hosting Leadership Retreat.\nWould you each kindly give 5 minutes overview in your respective areas of leadership on a panel regarding the following\nurgent threats, in particular:\nIran: Bill Burns\nMiddle East: George Mitchell\nAf/PaK: Richard Holbrooke\nNorth Korea: Eric Bosworth\nWould you please advise Nora Toiv, who is copied on this message if you cannot present.\nThanks so much.\ncdm\nUNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05759828 Date: 06/30/2015\n                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     ...
# UNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05773067 Date: 08/31/2015\nRELEASE IN PART\nB5\nFrom: H <hrod17@clintonemail.com>\nSent: Tuesday, January 5, 2010 9:32 PM\nTo: 'muscatinel@state.gov'\nSubject: Re: New top for development\nGood. Thx.\nOriginal Message\nFrom: Muscatine, Lissa <MuscatineL@state.gov>\nTo: H\nCc: Abedin, Huma <AbedinH@state.gov>\nSent: Tue Jan 05 21:26:20 2010\nSubject: New top for development\nHere is a new top. We will add the point about how much we actually spend on foreign aid (vs what people think we\nspend) a little later in the speech. Wanted to get this to you to see if it is going in the right direction. Am also faxing to\nyou.\nDevelopment / New Top\nUNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05773067 Date: 08/31/2015\nUNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05773067 Date: 08/31/2015\nUNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05773067 Date: 08/31/2015\n                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   ...
# UNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05765213 Date: 07/31/2015\nRELEASE IN PART\nB6\nFrom: Sullivan, Jacob J <SullivanJJ@state.gov>\nSent: Thursday, November 5, 2009 10:20 PM\nTo: H\nSubject Re: Memo: Berlin speeches. Sid\nTomicah, with Sid continuing to collaborate.\nOriginal Message ----\nFrom: H <HDR22@clintonemail.com>\nTo: Sullivan, Jacob i\nSent: Thu Nov 05 21:14:40 2009\nSubject: Re: Memo: Berlin speeches. Sid\nI hope we can achieve both power and poetry. Who is doing the short Monday remarks?\nOriginal Message ----\nFrom: Sullivan, Jacob J <Sullivan.1.1@state.gov>\nTo: H\nSent: Thu Nov 05 20:01:22 2009\nSubject: FW: Memo: Berlin speeches. Sid\nThe speechwriting crew is taking Sid's points below and massaging them into a set of remarks.\nFrom: sbwhoeop [mailto:sbwhoeop\nSent: Thursday, November 05, 2009 6:07 PM\nTo: hdr22@clintonemail.com\nCc: Imuscatine Sullivan, Jacob J\nSubject: Memo: Berlin speeches. Sid\nCONFIDENTIAL\nUNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05765213 Date: 07/31/2015\nUNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05765213 Date: 07/31/2015\nNovember 5, 2009-11-05\nFor Hillary:\nFrom: Sid\nCC: Lissa\nRe: Berlin speeches\nBelow are my notes for speeches in Berlin. The themes I stress are these: the importance of Berlin and the Brandenburg\nGate as symbols of freedom; the weight of history (always felt by Germans); the contribution of the US and the salience\nof the Western alliance; the meaning of 1989 to today and especially the continuity of the Western alliance; and segue\nfrom past to future.\nWhat I have not done here but might be added are references to Angela Merkel (a courageous woman from the east\nwho embodies the highest values of the West); and specific policies. Those can be fitted in.\nSo, some ideas and language:\nTwenty years ago the wall fell. Here, in Berlin, the moment when tens of thousands of citizens tore it down with\nhammers and picks and bare hands is called "Die Wende," a phrase that means more than simply a change but a turning\npoint in history. It was not only a turning point for Germany and Europe but also for the United States because the\nwall—the reason for its construction and the reason for its destruction—is central to our common history—and to our\ncommon future.\nRichard von Weizsaecker said, "As long as the Brandenburg Gate is closed, the German question will remain open."\nToday I can say with finality, the German question is closed, because the Brandenburg Gate is wide open! The gate is\nopen, Europe is open, and our future together is open.\nIn the forty years from the Berlin airlift to the fall of the Berlin Wall, the Atlantic partnership proved itself the most\nsuccessful alliance for freedom in history. That alliance was, is and shall be the crowning achievement of American\nforeign policy. And the German – American relationship has always served as its foundation. Our alliance represents the\nUNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05765213 Date: 07/31/2015\nUNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05765213 Date: 07/31/2015\nreconciliation of former enemies, an inspiration to other peoples and continents devastated by war and hatred, and it\nmust never be taken for granted.\nIn the twenty years since the fall of the wall we have created architecture for an enduring peace. Instead of a wall we\nhave built a gateway to the future. President Kennedy said in 1963 that in the future free men everywhere will say, "Ich\nbin ein Berliner." Today Berlin has gained a new and even more powerful meaning. Forever into the future, the opening\nof this Gate will be the symbol of the return of the dream of freedom, not only to Berlin and Germany, but to the entire\nworld.\nThe Gate, we must remember, was not built as a symbol of freedom. And each of the tyrannies that used the Gate as a\nsymbol believed it represented their eternal po ...
# ...
# UNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05774995 Date: 08/31/2015\nRELEASE IN FULL\nFrom: H <hrod17@clintonemail.com>\nSent: Tuesday, April 20, 2010 11:39 AM\nTo: 'abedinh@state.gov'\nCc: 'JilotyLC@state.gov'\nSubject: Re: Tony blair says he's free to talk anytime today. He's in middle east so is 8 hours\nahead.\nPls schedule so I can get this done.\nOriginal Message\nFrom: Abedin, Huma <AbedinH@state.gov>\nTo: H\nSent: Sun Apr 18 11:18:10 2010\nSubject: Tony blair says he's free to talk anytime today. He's in middle east so is 8 hours ahead.\nUNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05774995 Date: 08/31/2015\n                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ...
# UNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05761344 Date: 07/31/2015\nRELEASE IN PART B5,B6\nFrom: Mills, Cheryl D <MillsCD@state.gov>\nSent: Friday, April 24, 2009 4:35 PM\nTo: H\nSubject: RE: North Korea Human Rights Envoy\nI will -- EAP and Bosworth apparently are fine per below\nSo likely more judgment call.\nOriginal Message\nFrom: H [mailto:HDR22@clintonemail.com]\nSent: Friday, April 24, 2009 4:22 PM\nTo: Mills, Cheryl D\nSubject: Re: North Korea Human Rights Envoy\nHave you discussed w Bill Burns and Steve Bosworth?\nOriginal Message\nFrom: Mills, Cheryl D <MillsCD@state.gov>\nTo: H\nCc: Abedin, Huma <AbedinH@state.gov>\nSent: Fri Apr 24 13:50:06 2009\nSubject: FW: North Korea Human Rights Envoy\nif they now do believe a full-time slot is there?\ncdm\nFrom: Kennedy, Patrick F\nSent: Friday, April 24, 2009 8:08 AM\nTo: Mills, Cheryl D\nSubject: FW: North Korea Human Rights Envoy\nCheryl\nEAP has now provided me with the attached documents\nB6\nB5\nUNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05761344 Date: 07/31/2015\nUNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05761344 Date: 07/31/2015\nThere is 2004 legislation that call for an envoy and 2008 legislation [Sense of the Congress] that call for it to be full time\nPlus correspondence with Brownback by the previous administration [which isn't binding on the new]\nHowever, - - -\nThoughts?\nRegards\npat\nKurt W. Tong\nDirector for Korean Affairs\nU.S. Department of State\n(202)647-7719\nTongKW@state.gov\n17\nUNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05761344 Date: 07/31/2015\n                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ...
# UNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05768657 Date: 08/31/2015\nRELEASE IN PART\nB5\nFrom: Mills, Cheryl D <MillsCD@state.gov>\nSent: Tuesday, March 23, 2010 5:01 PM\nTo: H; Valmoro, Lona J\nSubject RE: Nita Lowey and AJC\nGreat - I have to brief her tomorrow on Haiti - I will tell her we are re-looking at it.\ncdm\nOriginal Message\nFrom: H [mailto:HDR22@clintonemail.com]\nSent: Tuesday, March 23, 2010 12:36 PM\nTo: Mills, Cheryl D; Valmoro, Lona J\nSubject: Re: Nita Lowey and AJC\nI think we should reconsider this invite.\nOriginal Message\nFrom: Mills, Cheryl D <MillsCD@state.gov>\nTo: H\nSent: Mon Mar 22 21:44:02 2010\nSubject: FW: Nita Lowey and AJC\nfyi\nFrom: Lew, Jacob\nSent: Monday, March 22, 2010 5:08 PM\nTo: Valmoro, Lona\nCc: Sullivan, Jacob i; Mills, Cheryl D\nSubject: Nita Lowey and AJC\nUNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05768657 Date: 08/31/2015\n                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    ...
# Name: RawText, dtype: int64

# %%
df_emails.RawText.count()
# Out:
# 908
